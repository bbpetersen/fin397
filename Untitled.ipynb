# %%
for j in range(2):     
    for i in ['a', 'b', 'c']:      
        print(i + str(j))
# Out:
# a0
# b0
# c0
# a1
# b1
# c1

# %%
  for i in ['a', 'b', 'c']: 
        for j in range(2):     
            print(i + str(j))
# Out:
# a0
# a1
# b0
# b1
# c0
# c1

# %%
import pandas as pd

# %%
t = pd.DataFrame({'A':[1,2,3],'B':[4,5,6], 'C':['a','b','c']})
t
# Out:
#    A  B  C
# 0  1  4  a
# 1  2  5  b
# 2  3  6  c

# %%
type(t.A)
# Out:
# pandas.core.series.Series

# %%
type(t['A'])
# Out:
# pandas.core.series.Series

# %%
t[['A']]
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
type (t[['A']])
# Out:
# pandas.core.frame.DataFrame

# %%
t = pd.DataFrame({'A':[1,2,3],'B':[4,5,6],})
t
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
t.A.iloc[0]
# Out:
# 1

# %%
t.A[:1]
# Out:
# 0    1
# Name: A, dtype: int64

# %%
type(t.A[:1])
# Out:
# pandas.core.series.Series

# %%
t = pd.DataFrame({'A':[1,2,2],'B':[4,5,6], 'C':['a','b','c']})
t
# Out:
#    A  B  C
# 0  1  4  a
# 1  2  5  b
# 2  2  6  c

# %%
t.loc[t.A==2, ['B', 'C']]
# Out:
#    B  C
# 1  5  b
# 2  6  c

# %%
t[t.A==2]['B', 'C']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('B', 'C')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-bc37a6d1cc15> in <module>
# ----> 1 t[t.A==2]['B', 'C']
#
# ...

# %%
t[t.A==2][['B', 'C']]
# Out:
#    B  C
# 1  5  b
# 2  6  c

# %%
t1 = pd.DataFrame({'A':[1], 'B':[2]})
t2 = pd.DataFrame({'A':[3], 'B':[4]})

# %%
t1
# Out:
#    A  B
# 0  1  2

# %%
t2
# Out:
#    A  B
# 0  3  4

# %%
t3 = t1.append(t2)
t3
# Out:
#    A  B
# 0  1  2
# 0  3  4

# %%
t1 = pd.DataFrame({'A':[1,2], 'B':[4,5]})        
t2 = pd.DataFrame({'A':[1,3], 'C':[6,7]})       

t3 = t1.merge(t2, on='A', how='right')

# %%
t1
# Out:
#    A  B
# 0  1  4
# 1  2  5

# %%
t2
# Out:
#    A  C
# 0  1  6
# 1  3  7

# %%
t3
# Out:
#    A    B  C
# 0  1  4.0  6
# 1  3  NaN  7

# %%
t=t3
t
# Out:
#    A    B  C
# 0  1  4.0  6
# 1  3  NaN  7

# %%
t[t.B.notnull()]
# Out:
#    A    B  C
# 0  1  4.0  6

# %%
t[t.B.isnull()]
# Out:
#    A   B  C
# 1  3 NaN  7

# %%
t.drop_duplicates()
# Out:
#    A    B  C
# 0  1  4.0  6
# 1  3  NaN  7

# %%
t1 = pd.DataFrame({'A':[1, 2, 3],'B':[4, 5, 6]}, index=['a', 'b', 'c'])
t2 = t1[(t1.A==1) | (t1.B!=5)]

# %%
t1
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6

# %%
t2
# Out:
#    A  B
# a  1  4
# c  3  6

# %% [markdown]
# ##QUIZ 4##

# %%
import pandas as pd
import numpy as np
import os

# %%
s = pd.Series([1,2,3,4,5,6], index = ['a','b','c','d','e','f'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
s[:'e'][-4:].sum()
# Out:
# 14

# %%
s[:'d'][-4:].sum()
# Out:
# 10

# %%
s[:'e'][-3:].sum()
# Out:
# 12

# %%
s[-4:][:'e'].sum()
# Out:
# 12

# %%
s[:'e'][-4:-1].sum()
# Out:
# 9

# %%
def where_are_my_socks(a, b='right here', c='!'):
    return b + c

# %%
where_are_my_socks(123, b='over there', '?')
# Out:
#   File "<ipython-input-53-8a293876e2c9>", line 1
#     where_are_my_socks(123, b='over there', '?')
#                                            ^
# SyntaxError: positional argument follows keyword argument

# %%
x = 'abc'
x
# Out:
# 'abc'

# %%
y = ['abc']
y
# Out:
# ['abc']

# %%
for i in x: print(i + 'z')
# Out:
# az
# bz
# cz

# %%
for i in y: print(i + 'z')
# Out:
# abcz

# %%
t1 = pd.DataFrame({'A':[1,2], 'B':[4,5]})
t2 = pd.DataFrame({'A':[1,3], 'C':[6,7]})

t1.join(t2, lsuffix='_this', rsuffix='_that')
# Out:
#    A_this  B  A_that  C
# 0       1  4       1  6
# 1       2  5       3  7

# %%
import pandas as pd
import numpy  as np
import os

# %%
t = pd.DataFrame({'A':[10,20,30]},index=['a','b','c'])
t
# Out:
#     A
# a  10
# b  20
# c  30

# %%
t.A['b']
# Out:
# 20

# %%
t.loc['b','A']
# Out:
# 20

# %%
t.loc['b'].A
# Out:
# 20

# %%
x = ['abc', '.def', 'hij']
x
# Out:
# ['abc', '.def', 'hij']

# %%
y = [s for s in x if not s.startswith('.')]
y
# Out:
# ['abc', 'hij']

# %%
t1 = pd.DataFrame({'A':[1,2,3]})
t2 = pd.DataFrame({'B':[4,5,6]})

d = {'a':t1, 'b':t2}

# %%
d
# Out:
# {'a':    A
#  0  1
#  1  2
#  2  3,
#  'b':    B
#  0  4
#  1  5
#  2  6}

# %%
type(d)
# Out:
# dict

# %%
d.t2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-9d07a3c3521b> in <module>
# ----> 1 d.t2
#
# AttributeError: 'dict' object has no attribute 't2'

# %%
d['a']
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
t2
# Out:
#    B
# 0  4
# 1  5
# 2  6

# %%
d['b']
# Out:
#    B
# 0  4
# 1  5
# 2  6

# %%
s = pd.Series([10,20,30,40], index=['a','b','c','d'])

# %%
for i in s.index:
    print(i + str(s[i]))
# Out:
# a10
# b20
# c30
# d40

# %%
for i, j in s.iteritems():
    print(i + str(j))
# Out:
# a10
# b20
# c30
# d40

# %%
s.a
# Out:
# 10

# %%
s.b
# Out:
# 20

# %%
t = pd.DataFrame({'revenue':[38,11,12,33,24], 'qtrs':[4,1,1,3,2]}, index=['2020q1','2020q2','2020q3','2020q4','2021q1'])
t
# Out:
#         revenue  qtrs
# 2020q1       38     4
# 2020q2       11     1
# 2020q3       12     1
# 2020q4       33     3
# 2021q1       24     2

# %%
t.revenue.loc['2020q4'] - t.revenue[:'2020q4'][-3:-1].sum()
# Out:
# 10

# %%
t.revenue.loc['2021q1'] + t.revenue[:'2021q1'][-4:-2].sum()
# Out:
# 47

# %%
def get_items_from_SEC_files(tags, filename=None):               

    directory = 'data/sec/merged/'                                
    filenames = [filename] if filename else os.listdir(directory) 
    filenames = [f for f in filenames if not f.startswith(".")]  

    results   = {t:pd.DataFrame() for t in tags}                  # Dictionary of tables (1 table for each tag)

    for filename in filenames:                                   
        print(filename)
        data = pd.read_csv(directory+filename, parse_dates=['filed','ddate']) 
        
        for t in tags:                                            
            item  = data[data.tag==t]                             
            short = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,False]) # Samllest qrts.
            long  = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,True])  # Largest  qtrs.
            short = short.groupby(['cik','filed']).last()[['value','qtrs']]    
            long  = long .groupby(['cik','filed']).last()[['value','qtrs']]     
            short_long = short.join(long, lsuffix='_shortest', rsuffix='_longest') # Put shortest and longest next to each other.
            results[t] = results[t].append( short_long )  
                        
    for t in tags:                                                # Now sort all tables by filing date.
        if not results[t].empty: results[t] = results[t].sort_index(level='filed')            

    return results

# %%
tags = ['OperatingIncomeLoss']
items = get_items_from_SEC_files(tags)
# Out:
# 2018q4.csv
# 2018q3.csv
# 2018q2.csv
# 2021_01.csv
# 2018q1.csv
# 2020q2.csv
# 2020q3.csv
# 2020q1.csv
# 2019q4.csv
# 2019q1.csv
# 2019q3.csv
# 2019q2.csv
# 2013q4.csv
# 2015q2.csv
# 2015q3.csv
# 2017q1.csv
# 2020_12.csv
# 2020_10.csv
# 2017q3.csv
# 2015q1.csv
# 2017q2.csv
# 2011q4.csv
# 2020_11.csv
# 2013q2.csv
# 2015q4.csv
# 2011q1.csv
# 2013q3.csv
# 2013q1.csv
# 2011q3.csv
# 2017q4.csv
# 2011q2.csv
# 2009q4.csv
# 2014q1.csv
# 2016q3.csv
# 2010q4.csv
# 2016q2.csv
# 2014q2.csv
# 2012q4.csv
# 2016q1.csv
# 2014q3.csv
# 2009q2.csv
# 2010q3.csv
# 2012q1.csv
# 2010q2.csv
# 2016q4.csv
# 2009q3.csv
# 2009q1.csv
# 2014q4.csv
# 2012q2.csv
# 2012q3.csv
# 2010q1.csv

# %%
def calculate_quarterly_values(item):                              # item: dataFrame
    result           = pd.DataFrame()                              # Results go here.
    all_firms        = item.index.get_level_values('cik').unique() # All unique CIKs
    all_filing_dates = pd.read_csv('data/sec/dates/filing_dates.csv', index_col='cik', parse_dates=['filed'])
    
    for cik in all_firms:                                          # Loop over all firms.  
        filing_dates = pd.Series(all_filing_dates.loc[cik].filed)  # All filing dates for this firm.
        values = item.loc[cik].value_shortest.reindex(filing_dates)
        qtrs   = item.loc[cik].qtrs_shortest.astype(int)
        for date,q in qtrs[qtrs>1].iteritems():                    # Loop over all dates with > 1 quarters. 
            previous_values = values[:date][-q:-1]                 # Example: for q=3 we need to subtract 2 previous quarters.            
            if len(previous_values) == q-1:                        # If all previous values available
                values[date] -= previous_values.sum(skipna=False)  # Subtract previous values.
            else:
                values[date]  = np.nan                  
        result = result.append( pd.DataFrame({'cik':cik, 'filed':values.index, 'value':values.values}) )

    return result.set_index(['cik','filed']).value   


def calculate_annual_values(item, values_1Q):                      # item: dataFrame; values_Q: series
    result           = pd.DataFrame()                              # Results go here.
    all_firms        = item.index.get_level_values('cik').unique() # All CIKs  
    all_filing_dates = pd.read_csv('data/sec/dates/filing_dates.csv', index_col='cik', parse_dates=['filed'])    
    
    for cik in all_firms:                                          # Loop over all firms.
        filing_dates = pd.Series(all_filing_dates.loc[cik].filed)  # All filing dates for this firm.
        valuesQ      = values_1Q.loc[cik].reindex(filing_dates)    # Use 1-quarter values (previously calculated).
        values       = item     .loc[cik].value_longest.reindex(filing_dates)
        qtrs         = item     .loc[cik].qtrs_longest.astype(int)
        for date,q in qtrs[qtrs<4].iteritems():                    # Loop over all dates with < 4 quarters. 
            previous_values = valuesQ[:date][-4:-q]                # Example: for q=2 we need to add quarters -3 and -4.
            if len(previous_values) == 4-q:                        # If all previous data available.     
                values[date] += previous_values.sum(skipna=False)  # Add previous values.
            else:
                values[date]  = np.nan
        result = result.append( pd.DataFrame({'cik':cik, 'filed':values.index, 'value':values.values}) )
                
    return result.set_index(['cik','filed']).value

# %%
item = items['OperatingIncomeLoss']

# %%
itemQ = calculate_quarterly_values(item)
itemQ
# Out:
# cik      filed
# 277948   2009-04-15    522000000.0
#          2009-07-15    582000000.0
#          2009-10-20    598000000.0
#          2010-02-19    583000000.0
#          2010-04-19    634000000.0
#                           ...
# 1437750  2021-01-25            NaN
# 1750106  2020-12-29      -265640.0
# 1160951  2021-01-13     -4246000.0
# 1824301  2021-01-19         -479.0
# 1816114  2021-01-20     -1442000.0
# Name: value, Length: 203810, dtype: float64

# %%
itemA = calculate_annual_values(item, itemQ)
itemA
# Out:
# cik      filed
# 277948   2009-04-15             NaN
#          2009-07-15             NaN
#          2009-10-20             NaN
#          2010-02-19    2.285000e+09
#          2010-04-19    2.397000e+09
#                            ...
# 1437750  2021-01-25   -4.055790e+05
# 1750106  2020-12-29             NaN
# 1160951  2021-01-13             NaN
# 1824301  2021-01-19             NaN
# 1816114  2021-01-20             NaN
# Name: value, Length: 203810, dtype: float64

# %%
itemA.max()/(10**9)
# Out:
# 74.253

# %%
symbols = pd.read_json('https://www.sec.gov/files/company_tickers.json').transpose().set_index('cik_str')
symbols
# Out:
#           ticker                             title
# cik_str
# 320193      AAPL                        Apple Inc.
# 789019      MSFT                    MICROSOFT CORP
# 1018724     AMZN                    AMAZON COM INC
# 1652044     GOOG                     Alphabet Inc.
# 1293451    TCEHY              Tencent Holdings Ltd
# ...          ...                               ...
# 1830081    CFVIU           CF Acquisition Corp. VI
# 1830210  STPC-UN                 Star Peak Corp II
# 1830188    DHHCU        DiamondHead Holdings Corp.
# 1830531    PAQCU       Provident Acquisition Corp.
# 1830795  QFTA-UN  Quantum FinTech Acquisition Corp
#
# [11190 rows x 2 columns]

# %%
FB = symbols[symbols.ticker=='FB'].index[0]  
FB
# Out:
# 1326801

# %%
s=itemQ.loc[FB]
s
# Out:
# filed
# 2012-07-31   -7.430000e+08
# 2012-10-24    3.770000e+08
# 2013-02-01             NaN
# 2013-05-02    3.730000e+08
# 2013-07-25    5.620000e+08
# 2013-11-01    7.360000e+08
# 2014-01-31    1.133000e+09
# 2014-04-25    1.075000e+09
# 2014-07-24    1.390000e+09
# 2014-10-30    1.397000e+09
# 2015-01-29    1.132000e+09
# 2015-04-23    9.330000e+08
# 2015-07-31    1.273000e+09
# 2015-11-05    1.459000e+09
# 2016-01-28    2.560000e+09
# 2016-04-28    2.009000e+09
# 2016-07-28    2.746000e+09
# 2016-11-03    3.122000e+09
# 2017-02-03    4.550000e+09
# 2017-05-04    3.327000e+09
# 2017-07-27    4.401000e+09
# 2017-11-02    5.122000e+09
# 2018-02-01    7.353000e+09
# 2018-04-26    5.449000e+09
# 2018-07-26    5.863000e+09
# 2018-10-31    5.781000e+09
# 2019-01-31    7.820000e+09
# 2019-04-25    3.317000e+09
# 2019-07-25    4.626000e+09
# 2019-10-31    7.185000e+09
# 2020-01-30    8.858000e+09
# 2020-04-30    5.893000e+09
# 2020-07-31    5.963000e+09
# 2020-10-30    8.040000e+09
# ...

# %%
s.pct_change()
# Out:
# filed
# 2012-07-31         NaN
# 2012-10-24   -1.507402
# 2013-02-01    0.000000
# 2013-05-02   -0.010610
# 2013-07-25    0.506702
# 2013-11-01    0.309609
# 2014-01-31    0.539402
# 2014-04-25   -0.051192
# 2014-07-24    0.293023
# 2014-10-30    0.005036
# 2015-01-29   -0.189692
# 2015-04-23   -0.175795
# 2015-07-31    0.364416
# 2015-11-05    0.146112
# 2016-01-28    0.754626
# 2016-04-28   -0.215234
# 2016-07-28    0.366849
# 2016-11-03    0.136926
# 2017-02-03    0.457399
# 2017-05-04   -0.268791
# 2017-07-27    0.322813
# 2017-11-02    0.163826
# 2018-02-01    0.435572
# 2018-04-26   -0.258942
# 2018-07-26    0.075977
# 2018-10-31   -0.013986
# 2019-01-31    0.352707
# 2019-04-25   -0.575831
# 2019-07-25    0.394634
# 2019-10-31    0.553178
# 2020-01-30    0.232846
# 2020-04-30   -0.334726
# 2020-07-31    0.011878
# 2020-10-30    0.348315
# 2021-01-28    0.588930
# Name: value, dtype: float64

# %%
s=itemQ.loc[FB][2:]
s
# Out:
# filed
# 2013-02-01             NaN
# 2013-05-02    3.730000e+08
# 2013-07-25    5.620000e+08
# 2013-11-01    7.360000e+08
# 2014-01-31    1.133000e+09
# 2014-04-25    1.075000e+09
# 2014-07-24    1.390000e+09
# 2014-10-30    1.397000e+09
# 2015-01-29    1.132000e+09
# 2015-04-23    9.330000e+08
# 2015-07-31    1.273000e+09
# 2015-11-05    1.459000e+09
# 2016-01-28    2.560000e+09
# 2016-04-28    2.009000e+09
# 2016-07-28    2.746000e+09
# 2016-11-03    3.122000e+09
# 2017-02-03    4.550000e+09
# 2017-05-04    3.327000e+09
# 2017-07-27    4.401000e+09
# 2017-11-02    5.122000e+09
# 2018-02-01    7.353000e+09
# 2018-04-26    5.449000e+09
# 2018-07-26    5.863000e+09
# 2018-10-31    5.781000e+09
# 2019-01-31    7.820000e+09
# 2019-04-25    3.317000e+09
# 2019-07-25    4.626000e+09
# 2019-10-31    7.185000e+09
# 2020-01-30    8.858000e+09
# 2020-04-30    5.893000e+09
# 2020-07-31    5.963000e+09
# 2020-10-30    8.040000e+09
# 2021-01-28    1.277500e+10
# Name: value, dtype: float64

# %%
s.pct_change()
# Out:
# filed
# 2013-02-01         NaN
# 2013-05-02         NaN
# 2013-07-25    0.506702
# 2013-11-01    0.309609
# 2014-01-31    0.539402
# 2014-04-25   -0.051192
# 2014-07-24    0.293023
# 2014-10-30    0.005036
# 2015-01-29   -0.189692
# 2015-04-23   -0.175795
# 2015-07-31    0.364416
# 2015-11-05    0.146112
# 2016-01-28    0.754626
# 2016-04-28   -0.215234
# 2016-07-28    0.366849
# 2016-11-03    0.136926
# 2017-02-03    0.457399
# 2017-05-04   -0.268791
# 2017-07-27    0.322813
# 2017-11-02    0.163826
# 2018-02-01    0.435572
# 2018-04-26   -0.258942
# 2018-07-26    0.075977
# 2018-10-31   -0.013986
# 2019-01-31    0.352707
# 2019-04-25   -0.575831
# 2019-07-25    0.394634
# 2019-10-31    0.553178
# 2020-01-30    0.232846
# 2020-04-30   -0.334726
# 2020-07-31    0.011878
# 2020-10-30    0.348315
# 2021-01-28    0.588930
# Name: value, dtype: float64

# %%
s.pct_change().max()
# Out:
# 0.7546264564770391

# %%
import pandas as pd

from tiingo import TiingoClient                       
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})

import quandl  
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')

# %%
data = tiingo.get_dataframe('TSLA', '1900-1-1')   
data
# Out:
#                             close      high       low    open    volume  \
# date
# 2010-06-29 00:00:00+00:00   23.89   25.0000   17.5400   19.00  18766300
# 2010-06-30 00:00:00+00:00   23.83   30.4192   23.3000   25.79  17187100
# 2010-07-01 00:00:00+00:00   21.96   25.9200   20.2700   25.00   8218800
# 2010-07-02 00:00:00+00:00   19.20   23.1000   18.7100   23.00   5139800
# 2010-07-06 00:00:00+00:00   16.11   20.0000   15.8300   20.00   6866900
# ...                           ...       ...       ...     ...       ...
# 2021-03-16 00:00:00+00:00  676.88  707.9200  671.0000  703.35  32195672
# 2021-03-17 00:00:00+00:00  701.81  703.7300  651.0100  656.87  40372453
# 2021-03-18 00:00:00+00:00  653.16  689.2300  652.0000  684.29  33369022
# 2021-03-19 00:00:00+00:00  654.87  657.2300  624.6201  646.60  42893978
# 2021-03-22 00:00:00+00:00  670.00  699.6200  668.7500  684.59  38791024
#
#                            adjClose    adjHigh    adjLow  adjOpen  adjVolume  \
# date
# ...

# %%
data.index = data.index.tz_convert(None)
data[-3:]
# Out:
#              close    high       low    open    volume  adjClose  adjHigh  \
# date
# 2021-03-18  653.16  689.23  652.0000  684.29  33369022    653.16   689.23
# 2021-03-19  654.87  657.23  624.6201  646.60  42893978    654.87   657.23
# 2021-03-22  670.00  699.62  668.7500  684.59  38791024    670.00   699.62
#
#               adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2021-03-18  652.0000   684.29   33369022      0.0          1.0
# 2021-03-19  624.6201   646.60   42893978      0.0          1.0
# 2021-03-22  668.7500   684.59   38791024      0.0          1.0

# %%
data.volume.mean()
# Out:
# 8312871.351721585

# %%
data.loc['2016-6', 'open']
# Out:
# date
# 2016-06-01    221.48
# 2016-06-02    219.59
# 2016-06-03    220.00
# 2016-06-06    218.00
# 2016-06-07    222.24
# 2016-06-08    233.80
# 2016-06-09    234.98
# 2016-06-10    227.39
# 2016-06-13    219.50
# 2016-06-14    218.88
# 2016-06-15    216.95
# 2016-06-16    217.42
# 2016-06-17    217.81
# 2016-06-20    219.50
# 2016-06-21    220.68
# 2016-06-22    199.47
# 2016-06-23    195.69
# 2016-06-24    190.05
# 2016-06-27    190.86
# 2016-06-28    201.89
# 2016-06-29    205.13
# 2016-06-30    212.97
# Name: open, dtype: float64

# %%
data.loc['2016-6', 'open'].max()
# Out:
# 234.98

# %%
data.loc['2016-6']['open'].max()
# Out:
# 234.98

# %%
data['open']['2016-6'].max()
# Out:
# 234.98

# %%
data.open['2016-6'].max()
# Out:
# 234.98

# %%
data.volume['2014-10'].mean()
# Out:
# 6615138.260869565

# %%
data.close['2018'][:100].max()
# Out:
# 357.42

# %%
data[data.volume>100*10**6]
# Out:
#              close    high       low    open     volume  adjClose  adjHigh  \
# date
# 2020-08-31  498.32  500.14  440.1100  444.61  115847020    498.32   500.14
# 2020-09-04  418.32  428.00  372.0201  402.81  110321885    418.32   428.00
# 2020-09-08  330.21  368.74  329.8800  356.00  115465691    330.21   368.74
# 2020-09-21  449.39  455.68  407.0700  453.13  109476800    449.39   455.68
# 2020-12-18  695.00  695.00  628.5400  668.90  222126194    695.00   695.00
#
#               adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2020-08-31  440.1100   444.61  115847020      0.0          5.0
# 2020-09-04  372.0201   402.81  110321885      0.0          1.0
# 2020-09-08  329.8800   356.00  115465691      0.0          1.0
# 2020-09-21  407.0700   453.13  109476800      0.0          1.0
# 2020-12-18  628.5400   668.90  222126194      0.0          1.0

# %%
data[data['volume']>100*10**6]
# Out:
#              close    high       low    open     volume  adjClose  adjHigh  \
# date
# 2020-08-31  498.32  500.14  440.1100  444.61  115847020    498.32   500.14
# 2020-09-04  418.32  428.00  372.0201  402.81  110321885    418.32   428.00
# 2020-09-08  330.21  368.74  329.8800  356.00  115465691    330.21   368.74
# 2020-09-21  449.39  455.68  407.0700  453.13  109476800    449.39   455.68
# 2020-12-18  695.00  695.00  628.5400  668.90  222126194    695.00   695.00
#
#               adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2020-08-31  440.1100   444.61  115847020      0.0          5.0
# 2020-09-04  372.0201   402.81  110321885      0.0          1.0
# 2020-09-08  329.8800   356.00  115465691      0.0          1.0
# 2020-09-21  407.0700   453.13  109476800      0.0          1.0
# 2020-12-18  628.5400   668.90  222126194      0.0          1.0

# %%
data[volume>100*10**6]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a724bd3f985f> in <module>
# ----> 1 data[volume>100*10**6]
#
# NameError: name 'volume' is not defined

# %%
data.loc[data.volume>100*10**6]
# Out:
#              close    high       low    open     volume  adjClose  adjHigh  \
# date
# 2020-08-31  498.32  500.14  440.1100  444.61  115847020    498.32   500.14
# 2020-09-04  418.32  428.00  372.0201  402.81  110321885    418.32   428.00
# 2020-09-08  330.21  368.74  329.8800  356.00  115465691    330.21   368.74
# 2020-09-21  449.39  455.68  407.0700  453.13  109476800    449.39   455.68
# 2020-12-18  695.00  695.00  628.5400  668.90  222126194    695.00   695.00
#
#               adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2020-08-31  440.1100   444.61  115847020      0.0          5.0
# 2020-09-04  372.0201   402.81  110321885      0.0          1.0
# 2020-09-08  329.8800   356.00  115465691      0.0          1.0
# 2020-09-21  407.0700   453.13  109476800      0.0          1.0
# 2020-12-18  628.5400   668.90  222126194      0.0          1.0

# %%
data[data.volume<5*10**6].close.mean()
# Out:
# 132.51196175359027

# %%
t1 = data[data.volume>100*10**6]
t2 = t1[data.close>450]
# Out:
# /Users/bradpetersen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
t1
# Out:
#              close    high       low    open     volume  adjClose  adjHigh  \
# date
# 2020-08-31  498.32  500.14  440.1100  444.61  115847020    498.32   500.14
# 2020-09-04  418.32  428.00  372.0201  402.81  110321885    418.32   428.00
# 2020-09-08  330.21  368.74  329.8800  356.00  115465691    330.21   368.74
# 2020-09-21  449.39  455.68  407.0700  453.13  109476800    449.39   455.68
# 2020-12-18  695.00  695.00  628.5400  668.90  222126194    695.00   695.00
#
#               adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2020-08-31  440.1100   444.61  115847020      0.0          5.0
# 2020-09-04  372.0201   402.81  110321885      0.0          1.0
# 2020-09-08  329.8800   356.00  115465691      0.0          1.0
# 2020-09-21  407.0700   453.13  109476800      0.0          1.0
# 2020-12-18  628.5400   668.90  222126194      0.0          1.0

# %%
t2
# Out:
#              close    high     low    open     volume  adjClose  adjHigh  \
# date
# 2020-08-31  498.32  500.14  440.11  444.61  115847020    498.32   500.14
# 2020-12-18  695.00  695.00  628.54  668.90  222126194    695.00   695.00
#
#             adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2020-08-31  440.11   444.61  115847020      0.0          5.0
# 2020-12-18  628.54   668.90  222126194      0.0          1.0

# %%
t1 = data[data.volume>100*10**6]
t2 = t1[t1.close>450]

# %%
data[(data.close>450) & (data.volume>100*10**6)]
# Out:
#              close    high     low    open     volume  adjClose  adjHigh  \
# date
# 2020-08-31  498.32  500.14  440.11  444.61  115847020    498.32   500.14
# 2020-12-18  695.00  695.00  628.54  668.90  222126194    695.00   695.00
#
#             adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2020-08-31  440.11   444.61  115847020      0.0          5.0
# 2020-12-18  628.54   668.90  222126194      0.0          1.0

# %%
data2 = tiingo.get_dataframe('UPS', '1900-1-1')   
data2
# Out:
#                             close      high     low    open    volume  \
# date
# 1999-11-10 00:00:00+00:00   68.25   70.3100   64.50   65.00  80793700
# 1999-11-11 00:00:00+00:00   75.00   76.9400   68.75   68.75  28309000
# 1999-11-12 00:00:00+00:00   70.50   76.6300   69.25   76.00  14768100
# 1999-11-15 00:00:00+00:00   69.00   70.8800   67.31   70.50   8675100
# 1999-11-16 00:00:00+00:00   66.00   68.0000   65.00   67.88   6978600
# ...                           ...       ...     ...     ...       ...
# 2021-03-16 00:00:00+00:00  162.82  164.1600  161.43  162.78   2397832
# 2021-03-17 00:00:00+00:00  160.65  161.7500  159.56  160.78   3644112
# 2021-03-18 00:00:00+00:00  160.20  161.1399  158.94  160.45   2966613
# 2021-03-19 00:00:00+00:00  159.29  165.2400  158.69  161.43  14934230
# 2021-03-22 00:00:00+00:00  161.06  161.7200  158.54  159.69   3893872
#
#                              adjClose     adjHigh      adjLow     adjOpen  \
# date
# ...

# %%
data2.index = data2.index.tz_convert(None)
data2[-3:]
# Out:
#              close      high     low    open    volume  adjClose   adjHigh  \
# date
# 2021-03-18  160.20  161.1399  158.94  160.45   2966613    160.20  161.1399
# 2021-03-19  159.29  165.2400  158.69  161.43  14934230    159.29  165.2400
# 2021-03-22  161.06  161.7200  158.54  159.69   3893872    161.06  161.7200
#
#             adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2021-03-18  158.94   160.45    2966613      0.0          1.0
# 2021-03-19  158.69   161.43   14934230      0.0          1.0
# 2021-03-22  158.54   159.69    3893872      0.0          1.0

# %%
data.loc['2015-08']
# Out:
#              close      high       low    open   volume   adjClose    adjHigh  \
# date
# 2015-08-03  102.75  103.1500  101.9001  102.49  2756871  85.828792  86.162918
# 2015-08-04  102.64  103.1200  102.2300  102.92  2431470  85.736907  86.137859
# 2015-08-05  102.94  104.0650  102.9400  103.05  3184667  85.987502  86.927233
# 2015-08-06  102.43  103.2200  102.2000  103.12  2042517  85.561490  86.221390
# 2015-08-07  102.14  102.4000  101.5000  102.33  2982862  85.319248  85.536431
# 2015-08-10  103.43  103.4800  102.7700  102.77  2689705  86.396807  86.438573
# 2015-08-11  102.99  103.4700  102.5300  102.63  3465171  86.029268  86.430220
# 2015-08-12  102.82  103.1200  101.5500  102.56  3868595  85.887264  86.137859
# 2015-08-13  101.84  102.3900  101.5020  101.95  1829867  85.678435  86.141152
# 2015-08-14  102.73  102.7625  101.3800  101.74  2279019  86.427195  86.454538
# 2015-08-17  102.90  102.9200  101.5400  102.24  2181724  86.570217  86.587043
# ...

# %%
data = tiingo.get_dataframe('MCD', '1900-1-1')   
data
# Out:
#                             close      high     low    open   volume  \
# date
# 1970-01-02 00:00:00+00:00   44.25   44.2500   43.00   43.00    23256
# 1970-01-05 00:00:00+00:00   45.00   45.0000   44.00   44.25    18193
# 1970-01-06 00:00:00+00:00   45.25   45.7500   45.00   45.00    16059
# 1970-01-07 00:00:00+00:00   45.00   45.7500   45.00   45.25    22459
# 1970-01-08 00:00:00+00:00   45.00   45.3800   45.00   45.00    18456
# ...                           ...       ...     ...     ...      ...
# 2021-03-16 00:00:00+00:00  219.86  221.3000  217.16  219.58  3583426
# 2021-03-17 00:00:00+00:00  224.11  224.9000  220.01  224.56  5240638
# 2021-03-18 00:00:00+00:00  222.90  225.3500  221.41  223.68  3254846
# 2021-03-19 00:00:00+00:00  222.44  225.1828  221.00  222.76  7719379
# 2021-03-22 00:00:00+00:00  225.07  226.9100  222.65  223.39  4220655
#
#                              adjClose     adjHigh      adjLow     adjOpen  \
# date
# ...

# %%
data.index = data.index.tz_convert(None)
data[-3:]
# Out:
#              close      high     low    open   volume  adjClose   adjHigh  \
# date
# 2021-03-18  222.90  225.3500  221.41  223.68  3254846    222.90  225.3500
# 2021-03-19  222.44  225.1828  221.00  222.76  7719379    222.44  225.1828
# 2021-03-22  225.07  226.9100  222.65  223.39  4220655    225.07  226.9100
#
#             adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2021-03-18  221.41   223.68    3254846      0.0          1.0
# 2021-03-19  221.00   222.76    7719379      0.0          1.0
# 2021-03-22  222.65   223.39    4220655      0.0          1.0

# %%
data[data.splitFactor!=1].count()
# Out:
# close          9
# high           9
# low            9
# open           9
# volume         9
# adjClose       9
# adjHigh        9
# adjLow         9
# adjOpen        9
# adjVolume      9
# divCash        9
# splitFactor    9
# dtype: int64

# %%
data['1980-1-1':'1990-1-1'].splitFactor[data.splitFactor!=1].cumprod()*10
# Out:
# date
# 1982-10-07     15.000
# 1984-09-25     22.500
# 1986-06-26     33.750
# 1987-06-23     50.625
# 1989-06-19    101.250
# Name: splitFactor, dtype: float64

# %%
data['1970-1-2':'2020-7-31'].splitFactor[data.splitFactor!=1].prod()
# Out:
# 121.5

# %%
data.close['2020-7-31']
# Out:
# 194.28

# %%
data['1970-1-2':'2020-7-31'].splitFactor[data.splitFactor!=1].prod()*data.close['2020-7-31']
# Out:
# 23605.02

# %%
data
# Out:
#              close      high     low    open   volume    adjClose     adjHigh  \
# date
# 1970-01-02   44.25   44.2500   43.00   43.00    23256    0.191379    0.191379
# 1970-01-05   45.00   45.0000   44.00   44.25    18193    0.194623    0.194623
# 1970-01-06   45.25   45.7500   45.00   45.00    16059    0.195704    0.197866
# 1970-01-07   45.00   45.7500   45.00   45.25    22459    0.194623    0.197866
# 1970-01-08   45.00   45.3800   45.00   45.00    18456    0.194623    0.196266
# ...            ...       ...     ...     ...      ...         ...         ...
# 2021-03-16  219.86  221.3000  217.16  219.58  3583426  219.860000  221.300000
# 2021-03-17  224.11  224.9000  220.01  224.56  5240638  224.110000  224.900000
# 2021-03-18  222.90  225.3500  221.41  223.68  3254846  222.900000  225.350000
# 2021-03-19  222.44  225.1828  221.00  222.76  7719379  222.440000  225.182800
# 2021-03-22  225.07  226.9100  222.65  223.39  4220655  225.070000  226.910000
#
# ...

# %%
shares = 1

for i in range(len(data[:'2020-7-31'])):
    shares = (shares + data.iloc[i].divCash * shares / data.iloc[i].close) * data.iloc[i].splitFactor
    
shares
# Out:
# 227.09395315689397

# %%
shares * data.close['2020-7-31']
# Out:
# 44119.81321932136

# %%
data2
# Out:
#              close      high     low    open    volume    adjClose  \
# date
# 1999-11-10   68.25   70.3100   64.50   65.00  80793700   40.038047
# 1999-11-11   75.00   76.9400   68.75   68.75  28309000   43.997853
# 1999-11-12   70.50   76.6300   69.25   76.00  14768100   41.357982
# 1999-11-15   69.00   70.8800   67.31   70.50   8675100   40.478025
# 1999-11-16   66.00   68.0000   65.00   67.88   6978600   38.718111
# ...            ...       ...     ...     ...       ...         ...
# 2021-03-16  162.82  164.1600  161.43  162.78   2397832  162.820000
# 2021-03-17  160.65  161.7500  159.56  160.78   3644112  160.650000
# 2021-03-18  160.20  161.1399  158.94  160.45   2966613  160.200000
# 2021-03-19  159.29  165.2400  158.69  161.43  14934230  159.290000
# 2021-03-22  161.06  161.7200  158.54  159.69   3893872  161.060000
#
#                adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# date
# 1999-11-10   41.246521   37.838154   38.131473   80793700      0.0
# ...

# %%
sharesUPS = 50/data2.close['2009-12-31']
sharesUPS
# Out:
# 0.8715356458079135

# %%
sharesUPS = 50/data2.close['2009-12-31']

for i in range(len(data2['2009-12-31':'2018-12-31'])):
    sharesUPS = sharesUPS + data2.iloc[i].divCash / data2.iloc[i].close
    sharesUPS = sharesUPS * data2.iloc[i].splitFactor
    
sharesUPS
# Out:
# 1.0233756578123077

# %%
sharesUPS
# Out:
# 1.0233756578123077

# %%
sharesUPS * data2.close['2018-12-31']
# Out:
# 99.80982790643436

# %%
data = tiingo.get_dataframe('IRBT', '1900-1-1')   
data
# Out:
#                             close      high       low    open   volume  \
# date
# 2005-11-09 00:00:00+00:00   26.70   34.1600   26.2900   29.51  5298000
# 2005-11-10 00:00:00+00:00   34.50   35.1600   31.3300   33.75  7776000
# 2005-11-11 00:00:00+00:00   36.51   37.3300   32.9900   34.50  4599400
# 2005-11-14 00:00:00+00:00   32.70   36.2000   32.7000   35.98  1877600
# 2005-11-15 00:00:00+00:00   30.60   33.6200   29.9800   32.24  1468600
# ...                           ...       ...       ...     ...      ...
# 2021-03-16 00:00:00+00:00  127.95  134.5000  124.6700  127.00   678648
# 2021-03-17 00:00:00+00:00  127.47  127.7300  121.5329  126.78   375506
# 2021-03-18 00:00:00+00:00  118.47  129.9900  117.4319  128.11   433450
# 2021-03-19 00:00:00+00:00  119.15  123.5465  116.9801  118.61   966674
# 2021-03-22 00:00:00+00:00  123.82  124.4900  118.7850  121.22   357059
#
#                            adjClose   adjHigh    adjLow  adjOpen  adjVolume  \
# date
# ...

# %%
data.index = data.index.tz_convert(None)
data[-3:]
# Out:
#              close      high       low    open  volume  adjClose   adjHigh  \
# date
# 2021-03-18  118.47  129.9900  117.4319  128.11  433450    118.47  129.9900
# 2021-03-19  119.15  123.5465  116.9801  118.61  966674    119.15  123.5465
# 2021-03-22  123.82  124.4900  118.7850  121.22  357059    123.82  124.4900
#
#               adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2021-03-18  117.4319   128.11     433450      0.0          1.0
# 2021-03-19  116.9801   118.61     966674      0.0          1.0
# 2021-03-22  118.7850   121.22     357059      0.0          1.0

# %%
data[['adjClose']].resample('W').last().pct_change().nsmallest(10, 'adjClose')
# Out:
#             adjClose
# date
# 2018-02-11 -0.346649
# 2012-02-12 -0.317212
# 2007-09-23 -0.248518
# 2019-04-28 -0.223413
# 2012-10-28 -0.219861
# 2011-08-07 -0.209564
# 2006-02-19 -0.204778
# 2005-11-20 -0.192002
# 2008-05-04 -0.184985
# 2009-07-26 -0.181960

# %%
data = tiingo.get_dataframe('CVX', '1970-1-1')   
data
# Out:
#                             close      high      low    open    volume  \
# date
# 1970-01-02 00:00:00+00:00   52.25   52.2500   51.120   51.12    131600
# 1970-01-05 00:00:00+00:00   52.50   52.8800   52.120   52.25    280400
# 1970-01-06 00:00:00+00:00   51.75   52.7500   51.500   52.50    138400
# 1970-01-07 00:00:00+00:00   51.62   51.8800   51.120   51.75    112800
# 1970-01-08 00:00:00+00:00   52.62   53.0000   52.250   52.25    158800
# ...                           ...       ...      ...     ...       ...
# 2021-03-16 00:00:00+00:00  107.64  108.8800  107.080  108.53  11698406
# 2021-03-17 00:00:00+00:00  108.03  108.5582  106.600  107.21   9168615
# 2021-03-18 00:00:00+00:00  104.12  107.5300  103.710  107.01  13246642
# 2021-03-19 00:00:00+00:00  103.38  104.8900  102.740  103.94  18490988
# 2021-03-22 00:00:00+00:00  102.54  104.5000  102.311  103.06  12508496
#
#                              adjClose     adjHigh      adjLow     adjOpen  \
# date
# ...

# %%
ret = data[['adjClose']].resample('M').last().pct_change()

# %%
ret
# Out:
#                            adjClose
# date
# 1970-01-31 00:00:00+00:00       NaN
# 1970-02-28 00:00:00+00:00  0.029922
# 1970-03-31 00:00:00+00:00 -0.063158
# 1970-04-30 00:00:00+00:00 -0.061798
# 1970-05-31 00:00:00+00:00  0.041916
# ...                             ...
# 2020-11-30 00:00:00+00:00  0.272979
# 2020-12-31 00:00:00+00:00 -0.031315
# 2021-01-31 00:00:00+00:00  0.008881
# 2021-02-28 00:00:00+00:00  0.189967
# 2021-03-31 00:00:00+00:00  0.025400
#
# [615 rows x 1 columns]

# %%
ret[ret.adjClose > 0.05].count()
# Out:
# adjClose    145
# dtype: int64

# %%
ret[ret.adjClose > 0.05].count() / ret.count()
# Out:
# adjClose    0.236156
# dtype: float64

# %%
rates = quandl.get(['FRED/FEDFUNDS','FRED/DGS1','FRED/DGS5','FRED/DGS10','FRED/DGS30']) / 100
rates
# Out:
#             FRED/FEDFUNDS - Value  FRED/DGS1 - Value  FRED/DGS5 - Value  \
# Date
# 1954-07-01                 0.0080                NaN                NaN
# 1954-08-01                 0.0122                NaN                NaN
# 1954-09-01                 0.0107                NaN                NaN
# 1954-10-01                 0.0085                NaN                NaN
# 1954-11-01                 0.0083                NaN                NaN
# ...                           ...                ...                ...
# 2021-03-15                    NaN             0.0008             0.0084
# 2021-03-16                    NaN             0.0007             0.0083
# 2021-03-17                    NaN             0.0007             0.0080
# 2021-03-18                    NaN             0.0008             0.0086
# 2021-03-19                    NaN             0.0007             0.0090
#
#             FRED/DGS10 - Value  FRED/DGS30 - Value
# Date
# ...

# %%
rates['FRED/DGS10 - Value']['2010-1-1':'2020-12-31'].max()
# Out:
# 0.0401

# %%
data = tiingo.get_dataframe('MCD', '1970-1-2','2020-7-31')   
data
# Out:
#                             close      high       low    open   volume  \
# date
# 1970-01-02 00:00:00+00:00   44.25   44.2500   43.0000   43.00    23256
# 1970-01-05 00:00:00+00:00   45.00   45.0000   44.0000   44.25    18193
# 1970-01-06 00:00:00+00:00   45.25   45.7500   45.0000   45.00    16059
# 1970-01-07 00:00:00+00:00   45.00   45.7500   45.0000   45.25    22459
# 1970-01-08 00:00:00+00:00   45.00   45.3800   45.0000   45.00    18456
# ...                           ...       ...       ...     ...      ...
# 2020-07-27 00:00:00+00:00  201.25  202.5200  198.7100  199.04  4541727
# 2020-07-28 00:00:00+00:00  196.24  199.8900  195.5000  198.60  6051015
# 2020-07-29 00:00:00+00:00  196.21  198.4600  195.7100  196.30  3342859
# 2020-07-30 00:00:00+00:00  195.41  196.4019  192.9201  195.00  2705661
# 2020-07-31 00:00:00+00:00  194.28  194.6750  191.6403  194.15  3195486
#
#                              adjClose     adjHigh      adjLow     adjOpen  \
# date
# ...

# %%
data.index = data.index.tz_convert(None)
data[-3:]
# Out:
#              close      high     low    open   volume  adjClose   adjHigh  \
# date
# 2021-03-18  222.90  225.3500  221.41  223.68  3254846    222.90  225.3500
# 2021-03-19  222.44  225.1828  221.00  222.76  7719379    222.44  225.1828
# 2021-03-22  225.07  226.9100  222.65  223.39  4220655    225.07  226.9100
#
#             adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2021-03-18  221.41   223.68    3254846      0.0          1.0
# 2021-03-19  221.00   222.76    7719379      0.0          1.0
# 2021-03-22  222.65   223.39    4220655      0.0          1.0

# %%
r = data.adjClose.pct_change()
r
# Out:
# date
# 1970-01-02 00:00:00+00:00         NaN
# 1970-01-05 00:00:00+00:00    0.016949
# 1970-01-06 00:00:00+00:00    0.005556
# 1970-01-07 00:00:00+00:00   -0.005525
# 1970-01-08 00:00:00+00:00    0.000000
#                                ...
# 2020-07-27 00:00:00+00:00    0.012731
# 2020-07-28 00:00:00+00:00   -0.024894
# 2020-07-29 00:00:00+00:00   -0.000153
# 2020-07-30 00:00:00+00:00   -0.004077
# 2020-07-31 00:00:00+00:00   -0.005783
# Name: adjClose, Length: 12758, dtype: float64

# %%
r.add(1).cumprod()
# Out:
# date
# 1970-01-02 00:00:00+00:00            NaN
# 1970-01-05 00:00:00+00:00       1.016949
# 1970-01-06 00:00:00+00:00       1.022599
# 1970-01-07 00:00:00+00:00       1.016949
# 1970-01-08 00:00:00+00:00       1.016949
#                                 ...
# 2020-07-27 00:00:00+00:00    1032.828431
# 2020-07-28 00:00:00+00:00    1007.116777
# 2020-07-29 00:00:00+00:00    1006.962815
# 2020-07-30 00:00:00+00:00    1002.857161
# 2020-07-31 00:00:00+00:00     997.057926
# Name: adjClose, Length: 12758, dtype: float64

# %%
data = tiingo.get_dataframe('IWV', '1900-1-1')   
data
# Out:
#                             close     high     low    open  volume  \
# date
# 2000-05-26 00:00:00+00:00   75.28   75.280   75.28   75.28     300
# 2000-05-30 00:00:00+00:00   77.44   77.440   76.03   76.03    1700
# 2000-05-31 00:00:00+00:00   78.27   78.270   77.69   77.69     700
# 2000-06-01 00:00:00+00:00   78.48   79.000   78.16   78.16     800
# 2000-06-02 00:00:00+00:00   80.98   81.250   80.97   81.25   19100
# ...                           ...      ...     ...     ...     ...
# 2021-03-16 00:00:00+00:00  238.70  240.025  238.14  239.86  114408
# 2021-03-17 00:00:00+00:00  239.53  240.080  237.04  237.70   92059
# 2021-03-18 00:00:00+00:00  235.53  239.125  235.11  237.78   84800
# 2021-03-19 00:00:00+00:00  235.33  236.460  233.83  235.61  131781
# 2021-03-22 00:00:00+00:00  236.76  237.810  235.58  235.58   80660
#
#                              adjClose     adjHigh      adjLow     adjOpen  \
# date
# ...

# %%
data.index = data.index.tz_convert(None)
data[-3:]
# Out:
#              close     high     low    open  volume  adjClose  adjHigh  \
# date
# 2021-03-18  235.53  239.125  235.11  237.78   84800    235.53  239.125
# 2021-03-19  235.33  236.460  233.83  235.61  131781    235.33  236.460
# 2021-03-22  236.76  237.810  235.58  235.58   80660    236.76  237.810
#
#             adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2021-03-18  235.11   237.78      84800      0.0          1.0
# 2021-03-19  233.83   235.61     131781      0.0          1.0
# 2021-03-22  235.58   235.58      80660      0.0          1.0

# %%
data[['adjClose']].groupby(data.index.year).last().pct_change()
# Out:
#       adjClose
# date
# 2000       NaN
# 2001 -0.114688
# 2002 -0.216410
# 2003  0.306529
# 2004  0.116964
# 2005  0.060757
# 2006  0.155180
# 2007  0.046945
# 2008 -0.371471
# 2009  0.282528
# 2010  0.168577
# 2011  0.007699
# 2012  0.164366
# 2013  0.330117
# 2014  0.123895
# 2015  0.003379
# 2016  0.126392
# 2017  0.209746
# 2018 -0.054111
# 2019  0.306600
# 2020  0.205483
# 2021  0.059092

# %%
daily = data['adjClose']['2010-1-1':'2020-12-31'].pct_change()

iwv = daily.add(1).resample('A').prod().sub(1)
iwv
# Out:
# date
# 2010-12-31    0.149212
# 2011-12-31    0.007699
# 2012-12-31    0.164366
# 2013-12-31    0.330117
# 2014-12-31    0.123895
# 2015-12-31    0.003379
# 2016-12-31    0.126392
# 2017-12-31    0.209746
# 2018-12-31   -0.054111
# 2019-12-31    0.306600
# 2020-12-31    0.205483
# Freq: A-DEC, Name: adjClose, dtype: float64

# %%
rates = quandl.get(['FRED/DGS1'])
rates
# Out:
#             FRED/DGS1 - Value
# Date
# 1962-01-02               3.22
# 1962-01-03               3.24
# 1962-01-04               3.24
# 1962-01-05               3.26
# 1962-01-08               3.31
# ...                       ...
# 2021-03-15               0.08
# 2021-03-16               0.07
# 2021-03-17               0.07
# 2021-03-18               0.08
# 2021-03-19               0.07
#
# [14788 rows x 1 columns]

# %%
treas = rates['FRED/DGS1 - Value']['2010-1-1':'2020-12-31'].resample('A').first()
treas = treas/100
treas
# Out:
# Date
# 2010-12-31    0.0045
# 2011-12-31    0.0029
# 2012-12-31    0.0012
# 2013-12-31    0.0015
# 2014-12-31    0.0013
# 2015-12-31    0.0025
# 2016-12-31    0.0061
# 2017-12-31    0.0089
# 2018-12-31    0.0183
# 2019-12-31    0.0260
# 2020-12-31    0.0156
# Freq: A-DEC, Name: FRED/DGS1 - Value, dtype: float64

# %%
answer = iwv - treas
answer
# Out:
# date
# 2010-12-31    0.144712
# 2011-12-31    0.004799
# 2012-12-31    0.163166
# 2013-12-31    0.328617
# 2014-12-31    0.122595
# 2015-12-31    0.000879
# 2016-12-31    0.120292
# 2017-12-31    0.200846
# 2018-12-31   -0.072411
# 2019-12-31    0.280600
# 2020-12-31    0.189883
# Freq: A-DEC, dtype: float64

# %%
answer.mean()
# Out:
# 0.13490723945078084

# %%
t = pd.DataFrame({'A':[1,2],'B':[3,4]})
t
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
s = pd.Series({'B':0.4, 'A':0.6})
s
# Out:
# B    0.4
# A    0.6
# dtype: float64

# %%
t*s
# Out:
#      A    B
# 0  0.6  1.2
# 1  1.2  1.6

# %%
s1 = pd.Series({'a':1, 'b':2})
s1
# Out:
# a    1
# b    2
# dtype: int64

# %%
s2 = pd.Series({'c':1, 'd':2})
s2
# Out:
# c    1
# d    2
# dtype: int64

# %%
s1.index.union(s2.index)
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
PRICE       = tiingo.get_dataframe(['CVX','COST'],'2000-01-01', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
PRICE[-3:]
# Out:
#                CVX    COST
# 2021-03-25  105.07  346.34
# 2021-03-26  107.48  352.02
# 2021-03-29  106.92  356.15

# %%
RET = PRICE.pct_change()
RET
# Out:
#                  CVX      COST
# 2000-01-03       NaN       NaN
# 2000-01-04  0.000000 -0.054719
# 2000-01-05  0.021643  0.016998
# 2000-01-06  0.038741  0.020103
# 2000-01-07  0.017577  0.066224
# ...              ...       ...
# 2021-03-23 -0.005559  0.017489
# 2021-03-24  0.026773 -0.006758
# 2021-03-25  0.003534  0.024553
# 2021-03-26  0.022937  0.016400
# 2021-03-29 -0.005210  0.011732
#
# [5343 rows x 2 columns]

# %%
weights = pd.Series({'CVX':0.5, 'COST':0.5})
weights
# Out:
# CVX     0.5
# COST    0.5
# dtype: float64

# %%
RET*weights
# Out:
#                  CVX      COST
# 2000-01-03       NaN       NaN
# 2000-01-04  0.000000 -0.027360
# 2000-01-05  0.010821  0.008499
# 2000-01-06  0.019370  0.010051
# 2000-01-07  0.008789  0.033112
# ...              ...       ...
# 2021-03-23 -0.002779  0.008745
# 2021-03-24  0.013386 -0.003379
# 2021-03-25  0.001767  0.012277
# 2021-03-26  0.011469  0.008200
# 2021-03-29 -0.002605  0.005866
#
# [5343 rows x 2 columns]

# %%
r_equal_weight = (RET * weights).sum('columns') #sum the rows instead of the columns
r_equal_weight
# Out:
# 2000-01-03    0.000000
# 2000-01-04   -0.027360
# 2000-01-05    0.019320
# 2000-01-06    0.029422
# 2000-01-07    0.041901
#                 ...
# 2021-03-23    0.005965
# 2021-03-24    0.010007
# 2021-03-25    0.014044
# 2021-03-26    0.019669
# 2021-03-29    0.003261
# Length: 5343, dtype: float64

# %%
RET.join(r_equal_weight.rename('Equal_Weight')).add(1).cumprod()
# Out:
#                  CVX       COST  Equal_Weight
# 2000-01-03       NaN        NaN      1.000000
# 2000-01-04  1.000000   0.945281      0.972640
# 2000-01-05  1.021643   0.961348      0.991432
# 2000-01-06  1.061222   0.980674      1.020602
# 2000-01-07  1.079876   1.045618      1.063366
# ...              ...        ...           ...
# 2021-03-23  5.265911  10.855393     10.235667
# 2021-03-24  5.406893  10.782033     10.338099
# 2021-03-25  5.426000  11.046767     10.483283
# 2021-03-26  5.550457  11.227935     10.689474
# 2021-03-29  5.521538  11.359665     10.724333
#
# [5343 rows x 3 columns]

# %%
data = tiingo.get_dataframe('CVX', '2000-1-1','2020-12-31')   
data.index = data.index.tz_convert(None)
data
# Out:
#             close     high      low   open   volume   adjClose    adjHigh  \
# date
# 2000-01-03  83.63  85.8800  82.5600  85.88  2193800  19.364171  19.885149
# 2000-01-04  83.63  84.1300  82.5000  82.94  1851200  19.364171  19.479944
# 2000-01-05  85.44  86.5600  83.0600  83.06  2783800  19.783269  20.042600
# 2000-01-06  88.75  89.1900  85.3100  85.31  2176700  20.549685  20.651565
# 2000-01-07  90.31  90.8800  89.0000  90.00  2243700  20.910896  21.042877
# ...           ...      ...      ...    ...      ...        ...        ...
# 2020-12-24  85.33  85.9300  84.8100  85.93  3335646  84.164191  84.755993
# 2020-12-28  84.90  86.6300  84.6200  85.61  7963012  83.740066  85.446430
# 2020-12-29  84.61  85.7234  84.0500  85.26  7670818  83.454028  84.552216
# 2020-12-30  85.33  86.5750  84.5400  84.61  7901846  84.164191  85.392181
# 2020-12-31  84.45  85.1950  83.9601  84.90  8350679  83.296214  84.031035
#
#                adjLow    adjOpen  adjVolume  divCash  splitFactor
# date
# ...

# %%
shares1 = .50/data.close['2000-01-03']
shares1
# Out:
# 0.005978715771852206

# %%
shares1 = .50/data.close['2000-01-03']

for i in range(len(data['2000-01-03':'2020-12-31'])):
    shares1 = shares1 + data.iloc[i].divCash * shares1 / data.iloc[i].close
    shares1 = shares1 * data.iloc[i].splitFactor
    
shares1
# Out:
# 0.025468109348484463

# %%
v1 = shares1 * data.close['2020-12-31']
v1
# Out:
# 2.150781834479513

# %%
data2 = tiingo.get_dataframe('COST', '2000-1-1','2020-12-31')   
data2.index = data2.index.tz_convert(None)
data2
# Out:
#              close     high       low      open   volume    adjClose  \
# date
# 2000-01-03   89.00   91.060   87.9400   91.0600  3028700   31.352158
# 2000-01-04   84.13   89.130   83.9400   88.9400  2861400   29.636596
# 2000-01-05   85.56   85.690   83.6900   84.4400  3863200   30.140344
# 2000-01-06   87.28   89.130   86.5000   86.6300  3610700   30.746251
# 2000-01-07   93.06   93.250   86.8100   86.8800  2582400   32.782380
# ...            ...      ...       ...       ...      ...         ...
# 2020-12-24  364.58  365.335  361.4055  361.4055   972522  363.864235
# 2020-12-28  371.06  371.690  365.0754  365.5000  3195102  370.331513
# 2020-12-29  372.72  373.255  370.2600  372.2500  2072603  371.988254
# 2020-12-30  374.45  375.860  373.2828  374.2000  1777985  373.714858
# 2020-12-31  376.78  377.040  372.4600  374.9900  1628904  376.040283
#
#                adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# date
# ...

# %%
shares2 = .50/data2.close['2000-01-03']
shares2
# Out:
# 0.0056179775280898875

# %%
shares2 = .50/data2.close['2000-01-03']

for i in range(len(data2['2000-01-03':'2020-12-31'])):
    shares2 = shares2 + data2.iloc[i].divCash * shares2 / data2.iloc[i].close
    shares2 = shares2 * data2.iloc[i].splitFactor
    
shares2
# Out:
# 0.015916555631911362

# %%
v2 = shares2 * data2.close['2020-12-31']
v2
# Out:
# 5.997039830991563

# %%
v1 + v2
# Out:
# 8.147821665471076

# %%
PRICE       = tiingo.get_dataframe(['CVX','COST'],'2000-01-01', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
PRICE[-3:]
# Out:
#                CVX    COST
# 2021-03-25  105.07  346.34
# 2021-03-26  107.48  352.02
# 2021-03-29  106.92  356.15

# %%
PRICE.plot()

# %%
RET = PRICE.pct_change()
RET
# Out:
#                  CVX      COST
# 2000-01-03       NaN       NaN
# 2000-01-04  0.000000 -0.054719
# 2000-01-05  0.021643  0.016998
# 2000-01-06  0.038741  0.020103
# 2000-01-07  0.017577  0.066224
# ...              ...       ...
# 2021-03-23 -0.005559  0.017489
# 2021-03-24  0.026773 -0.006758
# 2021-03-25  0.003534  0.024553
# 2021-03-26  0.022937  0.016400
# 2021-03-29 -0.005210  0.011732
#
# [5343 rows x 2 columns]

# %%
weights = pd.Series({'CVX':0.5, 'COST':0.5})
weights
# Out:
# CVX     0.5
# COST    0.5
# dtype: float64

# %%
RET * weights
# Out:
#                  CVX      COST
# 2000-01-03       NaN       NaN
# 2000-01-04  0.000000 -0.027360
# 2000-01-05  0.010821  0.008499
# 2000-01-06  0.019370  0.010051
# 2000-01-07  0.008789  0.033112
# ...              ...       ...
# 2021-03-23 -0.002779  0.008745
# 2021-03-24  0.013386 -0.003379
# 2021-03-25  0.001767  0.012277
# 2021-03-26  0.011469  0.008200
# 2021-03-29 -0.002605  0.005866
#
# [5343 rows x 2 columns]

# %%
r_equal_weight = (RET * weights).sum('columns') #sum the rows instead of the columns
r_equal_weight
# Out:
# 2000-01-03    0.000000
# 2000-01-04   -0.027360
# 2000-01-05    0.019320
# 2000-01-06    0.029422
# 2000-01-07    0.041901
#                 ...
# 2021-03-23    0.005965
# 2021-03-24    0.010007
# 2021-03-25    0.014044
# 2021-03-26    0.019669
# 2021-03-29    0.003261
# Length: 5343, dtype: float64

# %%
RET.join(r_equal_weight.rename('Equal_Weight'))
# Out:
#                  CVX      COST  Equal_Weight
# 2000-01-03       NaN       NaN      0.000000
# 2000-01-04  0.000000 -0.054719     -0.027360
# 2000-01-05  0.021643  0.016998      0.019320
# 2000-01-06  0.038741  0.020103      0.029422
# 2000-01-07  0.017577  0.066224      0.041901
# ...              ...       ...           ...
# 2021-03-23 -0.005559  0.017489      0.005965
# 2021-03-24  0.026773 -0.006758      0.010007
# 2021-03-25  0.003534  0.024553      0.014044
# 2021-03-26  0.022937  0.016400      0.019669
# 2021-03-29 -0.005210  0.011732      0.003261
#
# [5343 rows x 3 columns]

# %%
RET.join(r_equal_weight.rename('Equal_Weight')).add(1).cumprod()
# Out:
#                  CVX       COST  Equal_Weight
# 2000-01-03       NaN        NaN      1.000000
# 2000-01-04  1.000000   0.945281      0.972640
# 2000-01-05  1.021643   0.961348      0.991432
# 2000-01-06  1.061222   0.980674      1.020602
# 2000-01-07  1.079876   1.045618      1.063366
# ...              ...        ...           ...
# 2021-03-23  5.265911  10.855393     10.235667
# 2021-03-24  5.406893  10.782033     10.338099
# 2021-03-25  5.426000  11.046767     10.483283
# 2021-03-26  5.550457  11.227935     10.689474
# 2021-03-29  5.521538  11.359665     10.724333
#
# [5343 rows x 3 columns]

# %%
RET.join(r_equal_weight.rename('Equal_Weight')).add(1).cumprod()['2020']
# Out:
#                  CVX       COST  Equal_Weight
# 2020-01-02  5.855248   8.969364      9.357227
# 2020-01-03  5.834996   8.976749      9.344897
# 2020-01-06  5.815227   8.979210      9.330347
# 2020-01-07  5.740969   8.965056      9.263422
# 2020-01-08  5.675391   9.067830      9.263612
# ...              ...        ...           ...
# 2020-12-24  4.346388  11.605716      9.579737
# 2020-12-28  4.324485  11.811994      9.640734
# 2020-12-29  4.309713  11.864837      9.645834
# 2020-12-30  4.346388  11.919909      9.709261
# 2020-12-31  4.301564  11.994080      9.689403
#
# [253 rows x 3 columns]

# %%
cum_ret = RET[1:].add(1).cumprod()
cum_ret
# Out:
#                  CVX       COST
# 2000-01-04  1.000000   0.945281
# 2000-01-05  1.021643   0.961348
# 2000-01-06  1.061222   0.980674
# 2000-01-07  1.079876   1.045618
# 2000-01-10  1.050819   1.067416
# ...              ...        ...
# 2021-03-23  5.265911  10.855393
# 2021-03-24  5.406893  10.782033
# 2021-03-25  5.426000  11.046767
# 2021-03-26  5.550457  11.227935
# 2021-03-29  5.521538  11.359665
#
# [5342 rows x 2 columns]

# %%
(cum_ret * weights).sum('columns')['2020']
# Out:
# 2020-01-02    7.412306
# 2020-01-03    7.405873
# 2020-01-06    7.397219
# 2020-01-07    7.353013
# 2020-01-08    7.371611
#                 ...
# 2020-12-24    7.976052
# 2020-12-28    8.068240
# 2020-12-29    8.087275
# 2020-12-30    8.133148
# 2020-12-31    8.147822
# Length: 253, dtype: float64

# %%
import pandas as pd
import numpy  as np

from tiingo import TiingoClient                       
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})

import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice.

# %%
PRICE       = tiingo.get_dataframe(['CVX', 'MSFT', 'JNJ'],'2000-01-01', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)

RET = PRICE.pct_change()
RET[-3:]
# Out:
#                  CVX      MSFT       JNJ
# 2021-03-25  0.003534 -0.013251  0.000371
# 2021-03-26  0.022937  0.017819  0.018275
# 2021-03-29 -0.005210 -0.005244  0.006730

# %%
def get_rebalance_dates(frequency):
    group = getattr(PRICE.index, frequency) 
    return PRICE[:1].index.union(PRICE.groupby([PRICE.index.year, group]).tail(1).index)


rebalance_dates = get_rebalance_dates('quarter') 
rebalance_dates
# Out:
# DatetimeIndex(['2000-01-03', '2000-03-31', '2000-06-30', '2000-09-29',
#                '2000-12-29', '2001-03-30', '2001-06-29', '2001-09-28',
#                '2001-12-31', '2002-03-28', '2002-06-28', '2002-09-30',
#                '2002-12-31', '2003-03-31', '2003-06-30', '2003-09-30',
#                '2003-12-31', '2004-03-31', '2004-06-30', '2004-09-30',
#                '2004-12-31', '2005-03-31', '2005-06-30', '2005-09-30',
#                '2005-12-30', '2006-03-31', '2006-06-30', '2006-09-29',
#                '2006-12-29', '2007-03-30', '2007-06-29', '2007-09-28',
#                '2007-12-31', '2008-03-31', '2008-06-30', '2008-09-30',
#                '2008-12-31', '2009-03-31', '2009-06-30', '2009-09-30',
#                '2009-12-31', '2010-03-31', '2010-06-30', '2010-09-30',
#                '2010-12-31', '2011-03-31', '2011-06-30', '2011-09-30',
#                '2011-12-30', '2012-03-30', '2012-06-29', '2012-09-28',
# ...

# %%
def run_backtest(frequency):   
    rebalance_dates = get_rebalance_dates(frequency)
    weights         = pd.Series({'CVX':0.3, 'MSFT':0.5, 'JNJ':0.2})
    portfolio_value = pd.Series(1,                        index=[rebalance_dates[0]])    
    trades          = pd.DataFrame(columns=weights.index, index=[rebalance_dates[0]])
    previous_positions = weights

    for i in range(len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]
        
        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
        
        new_positions = portfolio_value.iloc[-1] * weights
        
        start_to_end_positions = new_positions  * cum_ret
        
        portfolio_value = portfolio_value.append(start_to_end_positions.sum('columns'))  


            
        trades.loc[start_date]  = new_positions - previous_positions
        previous_positions      = start_to_end_positions.iloc[-1]

    return portfolio_value, trades

value, trades = run_backtest('quarter')
value
# Out:
# 2000-01-03    1.000000
# 2000-01-04    0.975766
# 2000-01-05    0.990358
# 2000-01-06    0.991029
# 2000-01-07    1.011350
#                 ...
# 2021-03-23    7.998349
# 2021-03-24    8.049263
# 2021-03-25    8.008676
# 2021-03-26    8.166050
# 2021-03-29    8.141559
# Length: 5343, dtype: float64

# %%
trades
# Out:
#                    CVX       MSFT        JNJ
# 2000-01-03           0          0          0
# 2000-03-31  -0.0514433  0.0157767  0.0356665
# 2000-06-30  0.00589334  0.0904809 -0.0963742
# 2000-09-29  -0.0393178  0.0498603 -0.0105425
# 2000-12-29  -0.0266236   0.063203 -0.0365794
# ...                ...        ...        ...
# 2019-12-31    0.132811 -0.0972149 -0.0355963
# 2020-03-31    0.483194  -0.433024 -0.0501697
# 2020-06-30  -0.0180107  -0.153142   0.171153
# 2020-09-30    0.318536  -0.199045   -0.11949
# 2020-12-31   -0.177551   0.130786  0.0467648
#
# [85 rows x 3 columns]

# %%
value['2000-08']
# Out:
# 2000-08-01    0.796984
# 2000-08-02    0.806658
# 2000-08-03    0.813032
# 2000-08-04    0.803857
# 2000-08-07    0.813601
# 2000-08-08    0.835142
# 2000-08-09    0.839642
# 2000-08-10    0.839177
# 2000-08-11    0.839305
# 2000-08-14    0.838184
# 2000-08-15    0.830102
# 2000-08-16    0.836850
# 2000-08-17    0.845090
# 2000-08-18    0.837832
# 2000-08-21    0.839021
# 2000-08-22    0.843464
# 2000-08-23    0.846404
# 2000-08-24    0.838711
# 2000-08-25    0.836696
# 2000-08-28    0.839519
# 2000-08-29    0.831402
# 2000-08-30    0.820270
# 2000-08-31    0.818583
# dtype: float64

# %%
turnover = trades.abs().sum('columns').div(2)
turnover
# Out:
# 2000-01-03    0.000000
# 2000-03-31    0.051443
# 2000-06-30    0.096374
# 2000-09-29    0.049860
# 2000-12-29    0.063203
#                 ...
# 2019-12-31    0.132811
# 2020-03-31    0.483194
# 2020-06-30    0.171153
# 2020-09-30    0.318536
# 2020-12-31    0.177551
# Length: 85, dtype: float64

# %%
PRICE       = tiingo.get_dataframe(['CVX', 'MSFT', 'JNJ'],'2000-01-01', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)

RET = PRICE.pct_change()
RET[-3:]
# Out:
#                  CVX      MSFT       JNJ
# 2021-03-25  0.003534 -0.013251  0.000371
# 2021-03-26  0.022937  0.017819  0.018275
# 2021-03-29 -0.005210 -0.005244  0.006730

# %%
def get_rebalance_dates(frequency):
    group = getattr(PRICE.index, frequency) 
    return PRICE[:1].index.union(PRICE.groupby([PRICE.index.year, group]).tail(1).index)


rebalance_dates = get_rebalance_dates('quarter') 
rebalance_dates
# Out:
# DatetimeIndex(['2000-01-03', '2000-03-31', '2000-06-30', '2000-09-29',
#                '2000-12-29', '2001-03-30', '2001-06-29', '2001-09-28',
#                '2001-12-31', '2002-03-28', '2002-06-28', '2002-09-30',
#                '2002-12-31', '2003-03-31', '2003-06-30', '2003-09-30',
#                '2003-12-31', '2004-03-31', '2004-06-30', '2004-09-30',
#                '2004-12-31', '2005-03-31', '2005-06-30', '2005-09-30',
#                '2005-12-30', '2006-03-31', '2006-06-30', '2006-09-29',
#                '2006-12-29', '2007-03-30', '2007-06-29', '2007-09-28',
#                '2007-12-31', '2008-03-31', '2008-06-30', '2008-09-30',
#                '2008-12-31', '2009-03-31', '2009-06-30', '2009-09-30',
#                '2009-12-31', '2010-03-31', '2010-06-30', '2010-09-30',
#                '2010-12-31', '2011-03-31', '2011-06-30', '2011-09-30',
#                '2011-12-30', '2012-03-30', '2012-06-29', '2012-09-28',
# ...

# %%
weights         = pd.Series({'CVX':0.3, 'MSFT':0.5, 'JNJ':0.2})

# %%
portfolio_value = pd.Series(1, index= [rebalance_dates [0]])
portfolio_value
# Out:
# 2000-01-03    1
# dtype: int64

# %%
start_date = rebalance_dates [0]
end_date   = rebalance_dates [1]

print('start:', start_date, 'end:', end_date)
# Out:
# start: 2000-01-03 00:00:00 end: 2000-03-31 00:00:00

# %%
cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
cum_ret
# Out:
#                  CVX      MSFT       JNJ
# 2000-01-04  1.000000  0.966198  0.963337
# 2000-01-05  1.021643  0.976407  0.978306
# 2000-01-06  1.061222  0.943720  1.004013
# 2000-01-07  1.079876  0.956074  1.046751
# 2000-01-10  1.050819  0.963023  1.020284
# ...              ...       ...       ...
# 2000-03-27  1.019567  0.892759  0.759325
# 2000-03-28  1.023425  0.894904  0.783820
# 2000-03-29  1.067073  0.919612  0.773586
# 2000-03-30  1.111564  0.886839  0.770212
# 2000-03-31  1.114579  0.911548  0.764768
#
# [62 rows x 3 columns]

# %%
portfolio_value.iloc[-1]
# Out:
# 1

# %%
new_positions = portfolio_value.iloc[-1] * weights 
new_positions
# Out:
# CVX     0.3
# MSFT    0.5
# JNJ     0.2
# dtype: float64

# %%
start_to_end_positions = new_positions * cum_ret
start_to_end_positions
# Out:
#                  CVX      MSFT       JNJ
# 2000-01-04  0.300000  0.483099  0.192667
# 2000-01-05  0.306493  0.488204  0.195661
# 2000-01-06  0.318367  0.471860  0.200803
# 2000-01-07  0.323963  0.478037  0.209350
# 2000-01-10  0.315246  0.481512  0.204057
# ...              ...       ...       ...
# 2000-03-27  0.305870  0.446380  0.151865
# 2000-03-28  0.307028  0.447452  0.156764
# 2000-03-29  0.320122  0.459806  0.154717
# 2000-03-30  0.333469  0.443420  0.154042
# 2000-03-31  0.334374  0.455774  0.152954
#
# [62 rows x 3 columns]

# %%
start_to_end_positions.sum('columns')
# Out:
# 2000-01-04    0.975766
# 2000-01-05    0.990358
# 2000-01-06    0.991029
# 2000-01-07    1.011350
# 2000-01-10    1.000814
#                 ...
# 2000-03-27    0.904115
# 2000-03-28    0.911243
# 2000-03-29    0.934645
# 2000-03-30    0.930931
# 2000-03-31    0.943101
# Length: 62, dtype: float64

# %%
start_to_end_positions.sum('columns')[-1:]*0.3
# Out:
# 2000-03-31    0.28293
# dtype: float64

# %%
portfolio_value = portfolio_value.append(start_to_end_positions.sum('columns'))
portfolio_value
# Out:
# 2000-01-03    1.000000
# 2000-01-04    0.975766
# 2000-01-05    0.990358
# 2000-01-06    0.991029
# 2000-01-07    1.011350
#                 ...
# 2000-03-27    0.904115
# 2000-03-28    0.911243
# 2000-03-29    0.934645
# 2000-03-30    0.930931
# 2000-03-31    0.943101
# Length: 63, dtype: float64

# %%
PRICE       = tiingo.get_dataframe(['CVX', 'COST', 'MSFT', 'JNJ'],'2000-01-01', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)

RET = PRICE.pct_change()
RET[-3:]
# Out:
#                  CVX      COST      MSFT       JNJ
# 2021-03-25  0.003534  0.024553 -0.013251  0.000371
# 2021-03-26  0.022937  0.016400  0.017819  0.018275
# 2021-03-29 -0.005210  0.011732 -0.005244  0.006730

# %%
weights         = pd.Series({'CVX':0.25, 'MSFT':0.25, 'JNJ':0.25, 'COST':0.25})

# %%
def get_rebalance_dates(frequency):
    group = getattr(PRICE.index, frequency) 
    return PRICE[:1].index.union(PRICE.groupby([PRICE.index.year, group]).tail(1).index)


rebalance_dates = get_rebalance_dates('quarter') 
rebalance_dates
# Out:
# DatetimeIndex(['2000-01-03', '2000-03-31', '2000-06-30', '2000-09-29',
#                '2000-12-29', '2001-03-30', '2001-06-29', '2001-09-28',
#                '2001-12-31', '2002-03-28', '2002-06-28', '2002-09-30',
#                '2002-12-31', '2003-03-31', '2003-06-30', '2003-09-30',
#                '2003-12-31', '2004-03-31', '2004-06-30', '2004-09-30',
#                '2004-12-31', '2005-03-31', '2005-06-30', '2005-09-30',
#                '2005-12-30', '2006-03-31', '2006-06-30', '2006-09-29',
#                '2006-12-29', '2007-03-30', '2007-06-29', '2007-09-28',
#                '2007-12-31', '2008-03-31', '2008-06-30', '2008-09-30',
#                '2008-12-31', '2009-03-31', '2009-06-30', '2009-09-30',
#                '2009-12-31', '2010-03-31', '2010-06-30', '2010-09-30',
#                '2010-12-31', '2011-03-31', '2011-06-30', '2011-09-30',
#                '2011-12-30', '2012-03-30', '2012-06-29', '2012-09-28',
# ...

# %%
def run_backtest(frequency):   
    rebalance_dates = get_rebalance_dates(frequency)
    weights         = pd.Series({'CVX':0.25, 'MSFT':0.25, 'JNJ':0.25, 'COST':0.25})
    portfolio_value = pd.Series(1,                        index=[rebalance_dates[0]])    
    trades          = pd.DataFrame(columns=weights.index, index=[rebalance_dates[0]])
    previous_positions = weights

    for i in range(len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]
        
        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
        
        new_positions = portfolio_value.iloc[-1] * weights
        
        start_to_end_positions = new_positions  * cum_ret
        
        portfolio_value = portfolio_value.append(start_to_end_positions.sum('columns'))  


            
        trades.loc[start_date]  = new_positions - previous_positions
        previous_positions      = start_to_end_positions.iloc[-1]

    return portfolio_value, trades

value, trades = run_backtest('quarter')
value
# Out:
# 2000-01-03    1.000000
# 2000-01-04    0.968704
# 2000-01-05    0.984426
# 2000-01-06    0.997407
# 2000-01-07    1.032080
#                 ...
# 2021-03-23    9.447541
# 2021-03-24    9.508091
# 2021-03-25    9.536797
# 2021-03-26    9.719303
# 2021-03-29    9.732202
# Length: 5343, dtype: float64

# %%
turnover = trades.abs().sum('columns').div(2)
turnover
# Out:
# 2000-01-03    0.000000
# 2000-03-31    0.077423
# 2000-06-30    0.128005
# 2000-09-29    0.045842
# 2000-12-29    0.060377
#                 ...
# 2019-12-31    0.201965
# 2020-03-31    0.511728
# 2020-06-30    0.335697
# 2020-09-30    0.405977
# 2020-12-31    0.180305
# Length: 85, dtype: float64

# %%
turnover['2010']
# Out:
# 2010-03-31    0.015877
# 2010-06-30    0.040492
# 2010-09-30    0.049469
# 2010-12-31    0.041841
# dtype: float64

# %%
turnover.resample('A').sum()
# Out:
# 2000-12-31    0.311648
# 2001-12-31    0.207920
# 2002-12-31    0.154598
# 2003-12-31    0.141108
# 2004-12-31    0.093013
# 2005-12-31    0.166395
# 2006-12-31    0.153719
# 2007-12-31    0.158830
# 2008-12-31    0.224453
# 2009-12-31    0.160264
# 2010-12-31    0.147679
# 2011-12-31    0.214669
# 2012-12-31    0.246106
# 2013-12-31    0.209423
# 2014-12-31    0.371674
# 2015-12-31    0.433830
# 2016-12-31    0.450084
# 2017-12-31    0.413313
# 2018-12-31    0.578379
# 2019-12-31    0.678494
# 2020-12-31    1.433708
# Freq: A-DEC, dtype: float64

# %%
t = turnover['2010'].sum()
t
# Out:
# 0.14767923075611966

# %%
v =value['2010'].mean()
v
# Out:
# 1.7247005489355967

# %%
t / v * 100
# Out:
# 8.562601249663906

# %%
turnover.resample('A').sum().div( value.resample('A').mean())
# Out:
# 2000-12-31    0.341677
# 2001-12-31    0.210833
# 2002-12-31    0.159811
# 2003-12-31    0.154611
# 2004-12-31    0.084633
# 2005-12-31    0.130947
# 2006-12-31    0.111373
# 2007-12-31    0.097075
# 2008-12-31    0.134147
# 2009-12-31    0.109480
# 2010-12-31    0.085626
# 2011-12-31    0.106011
# 2012-12-31    0.105958
# 2013-12-31    0.073154
# 2014-12-31    0.110738
# 2015-12-31    0.121993
# 2016-12-31    0.110745
# 2017-12-31    0.084451
# 2018-12-31    0.096967
# 2019-12-31    0.097872
# 2020-12-31    0.178785
# 2021-12-31         NaN
# Freq: A-DEC, dtype: float64

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                          # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice

# %% [markdown]
# QUESTION 1

# %%
280*1.2 / (280*1.2 + -80*1.02)
# Out:
# 1.320754716981132

# %% [markdown]
# QUESTION 2

# %%
600/500
# Out:
# 1.2

# %%
600 * 1.3 / (600*1.3 + -100*1.01)
# Out:
# 1.1487481590574373

# %%
(600*1.3 + -100*1.01)
# Out:
# 679.0

# %%
679* 1.2
# Out:
# 814.8

# %%
679*-.2
# Out:
# -135.8

# %%
814.8/(814.8-135.8)
# Out:
# 1.2

# %%
814.8 - 600*1.3
# Out:
# 34.799999999999955

# %% [markdown]
# QUESTION 3

# %%
PRICE       = tiingo.get_dataframe(['QQQ'],'1900-01-01', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)

# %%
RET = PRICE.pct_change()
RET[-3:]
# Out:
#                  QQQ
# 2021-03-31  0.015303
# 2021-04-01  0.017046
# 2021-04-05  0.019965

# %%
t = pd.DataFrame()
t['QQQ']          = RET.QQQ.add(1).cumprod()

t.plot()

# %%
hwm = t.cummax()
hwm.plot()

# %%
hwm[-3:]
# Out:
#                 QQQ
# 2021-03-31  7.56356
# 2021-04-01  7.56356
# 2021-04-05  7.56356

# %%
drawdown = t/hwm
drawdown
# Out:
#                  QQQ
# 1999-03-10       NaN
# 1999-03-11  1.000000
# 1999-03-12  0.975634
# 1999-03-15  1.000000
# 1999-03-16  1.000000
# ...              ...
# 2021-03-29  0.940114
# 2021-03-30  0.935382
# 2021-03-31  0.949696
# 2021-04-01  0.965885
# 2021-04-05  0.985169
#
# [5554 rows x 1 columns]

# %%
drawdown.plot()

# %%
1-drawdown.min()
# Out:
# QQQ    0.829711
# dtype: float64

# %% [markdown]
# QUESTION 4

# %%
hwm['2000-03']
# Out:
#                  QQQ
# 2000-03-01  2.108717
# 2000-03-02  2.108717
# 2000-03-03  2.175318
# 2000-03-06  2.192948
# 2000-03-07  2.192948
# 2000-03-08  2.192948
# 2000-03-09  2.252693
# 2000-03-10  2.252693
# 2000-03-13  2.252693
# 2000-03-14  2.252693
# 2000-03-15  2.252693
# 2000-03-16  2.252693
# 2000-03-17  2.252693
# 2000-03-20  2.252693
# 2000-03-21  2.252693
# 2000-03-22  2.252693
# 2000-03-23  2.272282
# 2000-03-24  2.302840
# 2000-03-27  2.307542
# 2000-03-28  2.307542
# 2000-03-29  2.307542
# 2000-03-30  2.307542
# 2000-03-31  2.307542

# %%
hwm['2015-02']
# Out:
#                  QQQ
# 2015-02-02  2.307542
# 2015-02-03  2.307542
# 2015-02-04  2.307542
# 2015-02-05  2.307542
# 2015-02-06  2.307542
# 2015-02-09  2.307542
# 2015-02-10  2.307542
# 2015-02-11  2.307542
# 2015-02-12  2.307542
# 2015-02-13  2.307542
# 2015-02-17  2.307542
# 2015-02-18  2.307542
# 2015-02-19  2.307542
# 2015-02-20  2.308601
# 2015-02-23  2.310944
# 2015-02-24  2.312647
# 2015-02-25  2.312647
# 2015-02-26  2.318610
# 2015-02-27  2.318610

# %%
hwm['2000-03-27':'2015-02-19']
# Out:
#                  QQQ
# 2000-03-27  2.307542
# 2000-03-28  2.307542
# 2000-03-29  2.307542
# 2000-03-30  2.307542
# 2000-03-31  2.307542
# ...              ...
# 2015-02-12  2.307542
# 2015-02-13  2.307542
# 2015-02-17  2.307542
# 2015-02-18  2.307542
# 2015-02-19  2.307542
#
# [3748 rows x 1 columns]

# %%
hwm['2000-03-27':'2015-02-19'].count()
# Out:
# QQQ    3748
# dtype: int64

# %% [markdown]
# QUESTION 5

# %%
PRICE       = tiingo.get_dataframe(['QQQ'],'1900-01-01', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)

# %%
RET = PRICE.pct_change()
RET[-3:]
# Out:
#                  QQQ
# 2021-03-31  0.015303
# 2021-04-01  0.017046
# 2021-04-05  0.019965

# %%
fedfunds = quandl.get(['FRED/FEDFUNDS']).rename(columns={'FRED/FEDFUNDS - Value':'Fedfunds'}) / 100 / 252
fedfunds[-3:]
# Out:
#             Fedfunds
# Date
# 2021-01-01  0.000004
# 2021-02-01  0.000003
# 2021-03-01  0.000003

# %%
RET = RET.join(fedfunds, how='outer')
RET['Fedfunds']   = RET.Fedfunds.ffill()
RET['MarginRate'] = RET.Fedfunds + 0.01/252
RET = RET.dropna()
RET
# Out:
#                  QQQ  Fedfunds  MarginRate
# 1999-03-11  0.004897  0.000191    0.000231
# 1999-03-12 -0.024366  0.000191    0.000231
# 1999-03-15  0.028971  0.000191    0.000231
# 1999-03-16  0.008738  0.000191    0.000231
# 1999-03-17 -0.007700  0.000191    0.000231
# ...              ...       ...         ...
# 2021-03-29 -0.000285  0.000003    0.000042
# 2021-03-30 -0.005033  0.000003    0.000042
# 2021-03-31  0.015303  0.000003    0.000042
# 2021-04-01  0.017046  0.000003    0.000042
# 2021-04-05  0.019965  0.000003    0.000042
#
# [5553 rows x 3 columns]

# %%
weights = pd.Series({'QQQ':1.3, 'MarginRate':-.3})
weights
# Out:
# QQQ           1.3
# MarginRate   -0.3
# dtype: float64

# %%
RET.multiply(weights).sum('columns').add(1).cumprod()[-10:]
# Out:
# 2021-03-22    7.695648
# 2021-03-23    7.651904
# 2021-03-24    7.484040
# 2021-03-25    7.467098
# 2021-03-26    7.612613
# 2021-03-29    7.609698
# 2021-03-30    7.559810
# 2021-03-31    7.710107
# 2021-04-01    7.880867
# 2021-04-05    8.085309
# dtype: float64

# %% [markdown]
# QUESTION 6

# %%
PRICE       = tiingo.get_dataframe(['QQQ'],'1900-01-01', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)

# %%
RET = PRICE.pct_change()
RET[-3:]
# Out:
#                  QQQ
# 2021-03-31  0.015303
# 2021-04-01  0.017046
# 2021-04-05  0.019965

# %%
fedfunds = quandl.get(['FRED/FEDFUNDS']).rename(columns={'FRED/FEDFUNDS - Value':'Fedfunds'}) / 100 / 252
fedfunds[-3:]
# Out:
#             Fedfunds
# Date
# 2021-01-01  0.000004
# 2021-02-01  0.000003
# 2021-03-01  0.000003

# %%
RET = RET.join(fedfunds, how='outer')
RET['Fedfunds']   = RET.Fedfunds.ffill()
RET['MarginRate'] = RET.Fedfunds + 0.01/252
RET = RET.dropna()
RET
# Out:
#                  QQQ  Fedfunds  MarginRate
# 1999-03-11  0.004897  0.000191    0.000231
# 1999-03-12 -0.024366  0.000191    0.000231
# 1999-03-15  0.028971  0.000191    0.000231
# 1999-03-16  0.008738  0.000191    0.000231
# 1999-03-17 -0.007700  0.000191    0.000231
# ...              ...       ...         ...
# 2021-03-29 -0.000285  0.000003    0.000042
# 2021-03-30 -0.005033  0.000003    0.000042
# 2021-03-31  0.015303  0.000003    0.000042
# 2021-04-01  0.017046  0.000003    0.000042
# 2021-04-05  0.019965  0.000003    0.000042
#
# [5553 rows x 3 columns]

# %%
weights = pd.Series({'QQQ':1.3, 'MarginRate':-.3})
weights
# Out:
# QQQ           1.3
# MarginRate   -0.3
# dtype: float64

# %%
RET.multiply(weights).sum('columns').add(1).cumprod()['2008']*1000
# Out:
# 2008-01-02    729.911368
# 2008-01-03    733.065873
# 2008-01-04    691.228449
# 2008-01-07    686.917606
# 2008-01-08    663.704257
#                  ...
# 2008-12-24    345.263647
# 2008-12-26    345.104849
# 2008-12-29    341.403801
# 2008-12-30    350.616635
# 2008-12-31    354.475828
# Length: 253, dtype: float64

# %%
RET.multiply(weights).sum('columns').add(1).cumprod()['2008'][-1:]*1000
# Out:
# 2008-12-31    354.475828
# dtype: float64

# %%
RET.multiply(weights).sum('columns').add(1).cumprod()['2008'][-1:]*1000/1.3 - RET.multiply(weights).sum('columns').add(1).cumprod()['2008'][-1:]*1000
# Out:
# 2008-12-31   -81.802114
# dtype: float64

# %% [markdown]
# QUESTION 7

# %%
positions = RET.add(1).cumprod().multiply(weights)
positions['2008']*1000
# Out:
#             Fedfunds  MarginRate          QQQ
# 2008-01-02       NaN -448.958607  1309.874737
# 2008-01-03       NaN -449.046617  1314.288586
# 2008-01-04       NaN -449.134645  1256.648905
# 2008-01-07       NaN -449.222689  1250.677227
# 2008-01-08       NaN -449.310751  1218.222451
# ...              ...         ...          ...
# 2008-12-24       NaN -462.138272   759.305454
# 2008-12-26       NaN -462.159545   759.044882
# 2008-12-29       NaN -462.180819   752.791165
# 2008-12-30       NaN -462.202094   768.425458
# 2008-12-31       NaN -462.223370   774.939746
#
# [253 rows x 3 columns]

# %% [markdown]
# QUESTION 8

# %%
l = positions.QQQ / (positions.sum('columns'))
l
# Out:
# 1999-03-11    1.298191
# 1999-03-12    1.308025
# 1999-03-15    1.296867
# 1999-03-16    1.293628
# 1999-03-17    1.296671
#                 ...
# 2021-03-29    1.064284
# 2021-03-30    1.064634
# 2021-03-31    1.063600
# 2021-04-01    1.062471
# 2021-04-05    1.061176
# Length: 5553, dtype: float64

# %%
l.max()
# Out:
# 3.459308119660693

# %% [markdown]
# QUESTION 9 & 10

# %%
def get_rebalance_dates(frequency):
    group = getattr(PRICE.index, frequency) 
    return PRICE[:1].index.union(PRICE.groupby([PRICE.index.year, group]).tail(1).index)



def run_backtest(frequency):   

    weights = pd.Series({'QQQ':1.3, 'MarginRate':-0.3})
    
    rebalance_dates = get_rebalance_dates(frequency)

    portfolio_value = pd.Series(1,                        index=[rebalance_dates[0]])    
    leverage        = pd.Series(weights.QQQ,                        index=[rebalance_dates[0]])
    
    trades          = pd.DataFrame(columns=weights.index, index=[rebalance_dates[0]])
    previous_positions = weights
    
    for i in range(len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
        
        new_positions = portfolio_value.iloc[-1] * weights    

        start_to_end_positions = new_positions  * cum_ret

        portfolio_value = portfolio_value.append(start_to_end_positions.sum('columns'))                  
        leverage = leverage.append(start_to_end_positions.QQQ / start_to_end_positions.sum('columns'))
        
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, leverage, trades


portfolio_value, leverage, trades = run_backtest('quarter')

portfolio_value.to_frame('Portfolio').join(RET.QQQ.add(1).cumprod()).plot(logy=True)

# %%
hwm = portfolio_value.cummax()
hwm
# Out:
# 1999-03-10    1.000000
# 1999-03-12    1.000000
# 1999-03-15    1.004930
# 1999-03-16    1.016264
# 1999-03-17    1.016264
#                 ...
# 2021-03-29    7.829400
# 2021-03-30    7.829400
# 2021-03-31    7.829400
# 2021-04-01    7.829400
# 2021-04-05    7.829400
# Length: 5553, dtype: float64

# %%
drawdown = portfolio_value / hwm
drawdown
# Out:
# 1999-03-10    1.000000
# 1999-03-12    0.968254
# 1999-03-15    1.000000
# 1999-03-16    1.000000
# 1999-03-17    0.989958
#                 ...
# 2021-03-29    0.923316
# 2021-03-30    0.917273
# 2021-03-31    0.935507
# 2021-04-01    0.956226
# 2021-04-05    0.980908
# Length: 5553, dtype: float64

# %%
drawdown.plot()

# %%
1 - drawdown.min()
# Out:
# 0.9217446318085432

# %% [markdown]
# QUIZ 9

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                          # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                       # Basic plot library.
plt.style.use('ggplot')                               # Make plots look nice

# %%
# start in 2005 since GLD not available earlier
PRICE = tiingo.get_dataframe(['SPY','GLD','TLT'], '2005-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
RET = PRICE.pct_change()
RET[:3]
# Out:
#                  SPY       GLD       TLT
# 2005-01-03       NaN       NaN       NaN
# 2005-01-04 -0.012219 -0.006509 -0.010480
# 2005-01-05 -0.006901 -0.001638  0.005352

# %%
RATES = quandl.get(['FRED/FEDFUNDS','FRED/DGS1','FRED/DGS5','FRED/DGS10','FRED/DGS30']) / 100
RATES.columns = ['FedFunds','Treasury_1', 'Treasury_5', 'Treasury_10', 'Treasury_30']
RATES
# Out:
#             FedFunds  Treasury_1  Treasury_5  Treasury_10  Treasury_30
# Date
# 1954-07-01    0.0080         NaN         NaN          NaN          NaN
# 1954-08-01    0.0122         NaN         NaN          NaN          NaN
# 1954-09-01    0.0107         NaN         NaN          NaN          NaN
# 1954-10-01    0.0085         NaN         NaN          NaN          NaN
# 1954-11-01    0.0083         NaN         NaN          NaN          NaN
# ...              ...         ...         ...          ...          ...
# 2021-04-02       NaN      0.0007      0.0097       0.0172       0.0235
# 2021-04-05       NaN      0.0006      0.0094       0.0173       0.0236
# 2021-04-06       NaN      0.0006      0.0088       0.0167       0.0232
# 2021-04-07       NaN      0.0006      0.0087       0.0168       0.0235
# 2021-04-08       NaN      0.0005      0.0085       0.0164       0.0232
#
# [15150 rows x 5 columns]

# %%
RET = RET.join(RATES.FedFunds.rename('MarginLoan'), how='outer')
RET['MarginLoan'] = RET.MarginLoan.ffill()/252 + 0.01/252           # Assume margin rate = fed funds rate + 100 bsp
RET = RET.dropna(subset=['SPY'])
RET
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2005-01-04 -0.012219 -0.006509 -0.010480    0.000130
# 2005-01-05 -0.006901 -0.001638  0.005352    0.000130
# 2005-01-06  0.005084 -0.012187  0.000680    0.000130
# 2005-01-07 -0.001433 -0.007355  0.002264    0.000130
# 2005-01-10  0.004728  0.002629  0.001581    0.000130
# ...              ...       ...       ...         ...
# 2021-04-06 -0.000591  0.008029  0.006793    0.000042
# 2021-04-07  0.001157 -0.002818 -0.006965    0.000042
# 2021-04-08  0.004747  0.010752  0.008255    0.000042
# 2021-04-09  0.007270 -0.007538 -0.003623    0.000042
# 2021-04-12  0.000365 -0.006064 -0.000436    0.000042
#
# [4095 rows x 4 columns]

# %%
r_annual       = RET[:'2020'].add(1).resample('A').prod().sub(1)
r_annual_Tbill = RATES.Treasury_1.resample('A').first()

rx_annual = r_annual.sub(r_annual_Tbill, 'rows').dropna()

meanx = rx_annual[['SPY','TLT','GLD']].mean()

cov     = RET[['SPY','TLT','GLD']].cov() * 252
cov_inv = pd.DataFrame(np.linalg.inv(cov), columns=cov.columns, index=cov.index)

meanx
# Out:
# SPY    0.093715
# TLT    0.066050
# GLD    0.089407
# dtype: float64

# %%
w_maxSharpe = cov_inv.dot(meanx) /  cov_inv.dot(meanx).sum()
w_maxSharpe
# Out:
# SPY    0.355533
# TLT    0.467273
# GLD    0.177195
# dtype: float64

# %%
w_minVol = cov_inv.sum() / cov_inv.sum().sum()
w_minVol
# Out:
# SPY    0.337251
# TLT    0.519326
# GLD    0.143423
# dtype: float64

# %%
t = pd.DataFrame()
t['SPY']        = RET.SPY
t['TLT']        = RET.TLT
t['GLD']        = RET.GLD
t['Max_Sharpe'] = RET.multiply(w_maxSharpe).sum('columns')
t['Min_Vol']    = RET.multiply(w_minVol)   .sum('columns')

t.add(1).cumprod().plot(logy=True)

# %%
def get_rebalance_dates(frequency):
    group = getattr(PRICE.index, frequency) 
    return PRICE[:1].index.union(PRICE.groupby([PRICE.index.year, group]).tail(1).index)



def run_backtest(frequency):   
    
    rebalance_dates = get_rebalance_dates(frequency) 

    portfolio_value = pd.Series(1,                      index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=RET.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=RET.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
        
        start_weights = select_weights(start_date)
        
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions  * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, weights, trades

# %%
def select_weights(date):
    
    if not RET[:date].empty:
        cov     = RET[['SPY','TLT','GLD']][:date][-100:].cov() * 252
        cov_inv = pd.DataFrame(np.linalg.inv(cov), columns=cov.columns, index=cov.index)
        
        w = cov_inv.sum() / cov_inv.sum().sum()
        
    else:
        w = pd.Series(1/3, index = ['SPY', 'TLT', 'GLD'])
    
    
    return w




min_vol, weights, trades = run_backtest('month')


t = RET[['SPY','TLT','GLD']].join( min_vol.pct_change().rename('MinVol') )
t.add(1).cumprod().plot()
t.add(1).cumprod().plot(logy=True)

# %%
annual_returns = t[:'2020'].add(1).resample('A').prod().sub(1)

x = pd.DataFrame()                        
x['Average_returns']   = annual_returns.mean()
x['Geometric_average'] = annual_returns.add(1).prod().pow(1/len(annual_returns)).sub(1)
x['Risk_premium']      = annual_returns.sub(r_annual_Tbill, 'rows').dropna().mean()
x['Volatility']        = t[:'2020'].std() * 252**0.5    
x['Sharpe_ratio']      = x.Risk_premium / x.Volatility
x
# Out:
#         Average_returns  Geometric_average  Risk_premium  Volatility  \
# SPY            0.109102           0.095103      0.093715    0.196220
# TLT            0.081438           0.071075      0.066050    0.142047
# GLD            0.104794           0.092954      0.089407    0.182457
# MinVol         0.100489           0.098068      0.085101    0.081891
#
#         Sharpe_ratio
# SPY         0.477600
# TLT         0.464988
# GLD         0.490014
# MinVol      1.039199

# %% [markdown]
# Question 1

# %%
date = '2018-12-31'

# %%
RET[['SPY','TLT','GLD']][:date][-100:]
# Out:
#                  SPY       TLT       GLD
# 2018-08-08 -0.000420  0.001011  0.002793
# 2018-08-09 -0.001366  0.008418 -0.001479
# 2018-08-10 -0.006700  0.007263 -0.000436
# 2018-08-13 -0.003743 -0.002072 -0.015084
# 2018-08-14  0.006381 -0.002242  0.000974
# ...              ...       ...       ...
# 2018-12-24 -0.026423  0.004970  0.010950
# 2018-12-26  0.050525 -0.010715 -0.003000
# 2018-12-27  0.007677  0.000167  0.007605
# 2018-12-28 -0.001290  0.008414  0.004064
# 2018-12-31  0.008759  0.003800  0.001569
#
# [100 rows x 3 columns]

# %%
RET[['SPY','TLT','GLD']][-100:][:date]
# Out:
# Empty DataFrame
# Columns: [SPY, TLT, GLD]
# Index: []

# %% [markdown]
# Question 2

# %% [markdown]
# Question 3

# %% [markdown]
# Question 4

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                          # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                       # Basic plot library.
plt.style.use('ggplot')                               # Make plots look nice

# %%
# start in 2005 since GLD not available earlier
PRICE = tiingo.get_dataframe(['SPY','GLD','TLT'], '2005-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
RET = PRICE.pct_change()
RET[:3]
# Out:
#                  SPY       GLD       TLT
# 2005-01-03       NaN       NaN       NaN
# 2005-01-04 -0.012219 -0.006509 -0.010480
# 2005-01-05 -0.006901 -0.001638  0.005352

# %%
RATES = quandl.get(['FRED/FEDFUNDS','FRED/DGS1','FRED/DGS5','FRED/DGS10','FRED/DGS30']) / 100
RATES.columns = ['FedFunds','Treasury_1', 'Treasury_5', 'Treasury_10', 'Treasury_30']
RATES
# Out:
#             FedFunds  Treasury_1  Treasury_5  Treasury_10  Treasury_30
# Date
# 1954-07-01    0.0080         NaN         NaN          NaN          NaN
# 1954-08-01    0.0122         NaN         NaN          NaN          NaN
# 1954-09-01    0.0107         NaN         NaN          NaN          NaN
# 1954-10-01    0.0085         NaN         NaN          NaN          NaN
# 1954-11-01    0.0083         NaN         NaN          NaN          NaN
# ...              ...         ...         ...          ...          ...
# 2021-04-05       NaN      0.0006      0.0094       0.0173       0.0236
# 2021-04-06       NaN      0.0006      0.0088       0.0167       0.0232
# 2021-04-07       NaN      0.0006      0.0087       0.0168       0.0235
# 2021-04-08       NaN      0.0005      0.0085       0.0164       0.0232
# 2021-04-09       NaN      0.0006      0.0087       0.0167       0.0234
#
# [15151 rows x 5 columns]

# %%
RET = RET.join(RATES.FedFunds.rename('MarginLoan'), how='outer')
RET['MarginLoan'] = RET.MarginLoan.ffill()/252 + 0.01/252           # Assume margin rate = fed funds rate + 100 bsp
RET = RET.dropna(subset=['SPY'])
RET
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2005-01-04 -0.012219 -0.006509 -0.010480    0.000130
# 2005-01-05 -0.006901 -0.001638  0.005352    0.000130
# 2005-01-06  0.005084 -0.012187  0.000680    0.000130
# 2005-01-07 -0.001433 -0.007355  0.002264    0.000130
# 2005-01-10  0.004728  0.002629  0.001581    0.000130
# ...              ...       ...       ...         ...
# 2021-04-06 -0.000591  0.008029  0.006793    0.000042
# 2021-04-07  0.001157 -0.002818 -0.006965    0.000042
# 2021-04-08  0.004747  0.010752  0.008255    0.000042
# 2021-04-09  0.007270 -0.007538 -0.003623    0.000042
# 2021-04-12  0.000365 -0.006064 -0.000436    0.000042
#
# [4095 rows x 4 columns]

# %%
r_annual       = RET['2009'].add(1).resample('A').prod().sub(1)

r_annual_Tbill = RATES.Treasury_1.resample('A').first()

rx_annual = r_annual.sub(r_annual_Tbill, 'rows').dropna()

meanx = rx_annual[['SPY','TLT','GLD']].mean()

cov     = RET['2009'][['SPY','TLT','GLD']].cov() * 252
cov_inv = pd.DataFrame(np.linalg.inv(cov), columns=cov.columns, index=cov.index)

meanx

#r_annual
#r_annual_Tbill
#rx_annual
# Out:
# SPY    0.259661
# TLT   -0.222006
# GLD    0.236291
# dtype: float64

# %%
w_minVol = cov_inv.sum() / cov_inv.sum().sum()
w_minVol
# Out:
# SPY    0.281381
# TLT    0.476143
# GLD    0.242477
# dtype: float64

# %% [markdown]
# Question 5

# %%
RET['2009']
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2009-01-02  0.030142 -0.003352 -0.025136    0.000046
# 2009-01-05 -0.001183 -0.020295 -0.025784    0.000046
# 2009-01-06  0.006677  0.007694 -0.010057    0.000046
# 2009-01-07 -0.029956 -0.027957  0.003921    0.000046
# 2009-01-08  0.004081  0.020665 -0.000799    0.000046
# ...              ...       ...       ...         ...
# 2009-12-24  0.004734  0.016987 -0.010370    0.000044
# 2009-12-28  0.002134  0.001753 -0.002787    0.000044
# 2009-12-29 -0.001419 -0.009949  0.006575    0.000044
# 2009-12-30 -0.000355 -0.005025  0.006575    0.000044
# 2009-12-31 -0.009598  0.003554 -0.004761    0.000044
#
# [252 rows x 4 columns]

# %%
RET['2009'].corr()
# Out:
#                  SPY       GLD       TLT  MarginLoan
# SPY         1.000000  0.036112 -0.323306   -0.048618
# GLD         0.036112  1.000000  0.099647   -0.041775
# TLT        -0.323306  0.099647  1.000000    0.050182
# MarginLoan -0.048618 -0.041775  0.050182    1.000000

# %% [markdown]
# Question 6

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                          # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                       # Basic plot library.
plt.style.use('ggplot')

# %%
# start in 2005 since GLD not available earlier
PRICE = tiingo.get_dataframe(['SPY','GLD','TLT'], '2005-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
RET = PRICE.pct_change()
RET[:3]
# Out:
#                  SPY       GLD       TLT
# 2005-01-03       NaN       NaN       NaN
# 2005-01-04 -0.012219 -0.006509 -0.010480
# 2005-01-05 -0.006901 -0.001638  0.005352

# %%
RATES = quandl.get(['FRED/FEDFUNDS','FRED/DGS1','FRED/DGS5','FRED/DGS10','FRED/DGS30']) / 100
RATES.columns = ['FedFunds','Treasury_1', 'Treasury_5', 'Treasury_10', 'Treasury_30']
RATES
# Out:
#             FedFunds  Treasury_1  Treasury_5  Treasury_10  Treasury_30
# Date
# 1954-07-01    0.0080         NaN         NaN          NaN          NaN
# 1954-08-01    0.0122         NaN         NaN          NaN          NaN
# 1954-09-01    0.0107         NaN         NaN          NaN          NaN
# 1954-10-01    0.0085         NaN         NaN          NaN          NaN
# 1954-11-01    0.0083         NaN         NaN          NaN          NaN
# ...              ...         ...         ...          ...          ...
# 2021-04-05       NaN      0.0006      0.0094       0.0173       0.0236
# 2021-04-06       NaN      0.0006      0.0088       0.0167       0.0232
# 2021-04-07       NaN      0.0006      0.0087       0.0168       0.0235
# 2021-04-08       NaN      0.0005      0.0085       0.0164       0.0232
# 2021-04-09       NaN      0.0006      0.0087       0.0167       0.0234
#
# [15151 rows x 5 columns]

# %%
RET = RET.join(RATES.FedFunds.rename('MarginLoan'), how='outer')
RET['MarginLoan'] = RET.MarginLoan.ffill()/252 + 0.01/252           # Assume margin rate = fed funds rate + 100 bsp
RET = RET.dropna(subset=['SPY'])
RET
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2005-01-04 -0.012219 -0.006509 -0.010480    0.000130
# 2005-01-05 -0.006901 -0.001638  0.005352    0.000130
# 2005-01-06  0.005084 -0.012187  0.000680    0.000130
# 2005-01-07 -0.001433 -0.007355  0.002264    0.000130
# 2005-01-10  0.004728  0.002629  0.001581    0.000130
# ...              ...       ...       ...         ...
# 2021-04-06 -0.000591  0.008029  0.006793    0.000042
# 2021-04-07  0.001157 -0.002818 -0.006965    0.000042
# 2021-04-08  0.004747  0.010752  0.008255    0.000042
# 2021-04-09  0.007270 -0.007538 -0.003623    0.000042
# 2021-04-12  0.000365 -0.006064 -0.000436    0.000042
#
# [4095 rows x 4 columns]

# %%
RET[:'2015']
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2005-01-04 -0.012219 -0.006509 -0.010480    0.000130
# 2005-01-05 -0.006901 -0.001638  0.005352    0.000130
# 2005-01-06  0.005084 -0.012187  0.000680    0.000130
# 2005-01-07 -0.001433 -0.007355  0.002264    0.000130
# 2005-01-10  0.004728  0.002629  0.001581    0.000130
# ...              ...       ...       ...         ...
# 2015-12-24 -0.001650  0.007233  0.005717    0.000049
# 2015-12-28 -0.002285 -0.007569  0.002955    0.000049
# 2015-12-29  0.010672 -0.000684 -0.016613    0.000049
# 2015-12-30 -0.007088 -0.007632 -0.000999    0.000049
# 2015-12-31 -0.010003  0.000394  0.004499    0.000049
#
# [2768 rows x 4 columns]

# %%
r_annual       = RET[:'2015'].add(1).resample('A').prod().sub(1)

r_annual_Tbill = RATES[:'2015'].Treasury_1.resample('A').first()

rx_annual = r_annual.sub(r_annual_Tbill, 'rows').dropna()

meanx = rx_annual[['SPY','TLT','GLD']].mean()

cov     = RET[['SPY','TLT','GLD']][:'2015'].cov() * 252
cov_inv = pd.DataFrame(np.linalg.inv(cov), columns=cov.columns, index=cov.index)

meanx

#r_annual
#r_annual_Tbill
#rx_annual
# Out:
# SPY    0.071540
# TLT    0.065586
# GLD    0.080881
# dtype: float64

# %%
w_maxSharpe = cov_inv.dot(meanx) /  cov_inv.dot(meanx).sum()
w_maxSharpe
# Out:
# SPY    0.330818
# TLT    0.505456
# GLD    0.163726
# dtype: float64

# %%
RET['2015-12-31':]
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2015-12-31 -0.010003  0.000394  0.004499    0.000049
# 2016-01-04 -0.013979  0.014094  0.007215    0.000053
# 2016-01-05  0.001691  0.002819 -0.004035    0.000053
# 2016-01-06 -0.012614  0.014441  0.013476    0.000053
# 2016-01-07 -0.023992  0.014140  0.001795    0.000053
# ...              ...       ...       ...         ...
# 2021-04-06 -0.000591  0.008029  0.006793    0.000042
# 2021-04-07  0.001157 -0.002818 -0.006965    0.000042
# 2021-04-08  0.004747  0.010752  0.008255    0.000042
# 2021-04-09  0.007270 -0.007538 -0.003623    0.000042
# 2021-04-12  0.000365 -0.006064 -0.000436    0.000042
#
# [1328 rows x 4 columns]

# %%
RET['2015-12-31':'2021-03-31'].add(1).cumprod()
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2015-12-31  0.989997  1.000394  1.004499    1.000049
# 2016-01-04  0.976157  1.014494  1.011746    1.000102
# 2016-01-05  0.977808  1.017354  1.007664    1.000156
# 2016-01-06  0.965474  1.032045  1.021243    1.000209
# 2016-01-07  0.942311  1.046638  1.023076    1.000262
# ...              ...       ...       ...         ...
# 2021-03-25  2.092050  1.595149  1.283034    1.116175
# 2021-03-26  2.125764  1.599684  1.278543    1.116222
# 2021-03-29  2.124690  1.580655  1.267691    1.116270
# 2021-03-30  2.119053  1.553638  1.274333    1.116317
# 2021-03-31  2.127643  1.577204  1.267223    1.116364
#
# [1321 rows x 4 columns]

# %%
RET['2015-12-31':'2021-03-31'].add(1).cumprod().multiply(w_maxSharpe)
# Out:
#                  GLD  MarginLoan       SPY       TLT
# 2015-12-31  0.163791         NaN  0.327509  0.507730
# 2016-01-04  0.166099         NaN  0.322930  0.511393
# 2016-01-05  0.166567         NaN  0.323476  0.509330
# 2016-01-06  0.168973         NaN  0.319396  0.516194
# 2016-01-07  0.171362         NaN  0.311733  0.517120
# ...              ...         ...       ...       ...
# 2021-03-25  0.261167         NaN  0.692088  0.648517
# 2021-03-26  0.261910         NaN  0.703241  0.646248
# 2021-03-29  0.258794         NaN  0.702886  0.640762
# 2021-03-30  0.254371         NaN  0.701021  0.644120
# 2021-03-31  0.258229         NaN  0.703862  0.640526
#
# [1321 rows x 4 columns]

# %%
RET['2015-12-31':'2021-03-31'].add(1).cumprod().multiply(w_maxSharpe).sum('columns')*1000
# Out:
# 2015-12-31     999.029065
# 2016-01-04    1000.422502
# 2016-01-05     999.373592
# 2016-01-06    1004.562050
# 2016-01-07    1000.214817
#                  ...
# 2021-03-25    1601.772489
# 2021-03-26    1611.398192
# 2021-03-29    1602.441843
# 2021-03-30    1599.511313
# 2021-03-31    1602.617154
# Length: 1321, dtype: float64

# %%
cum_ret = RET['2015-12-31':'2021-03-31'][0:].add(1).cumprod()

pos = w_maxSharpe * cum_ret

pos
# Out:
#                  GLD  MarginLoan       SPY       TLT
# 2015-12-31  0.163791         NaN  0.327509  0.507730
# 2016-01-04  0.166099         NaN  0.322930  0.511393
# 2016-01-05  0.166567         NaN  0.323476  0.509330
# 2016-01-06  0.168973         NaN  0.319396  0.516194
# 2016-01-07  0.171362         NaN  0.311733  0.517120
# ...              ...         ...       ...       ...
# 2021-03-25  0.261167         NaN  0.692088  0.648517
# 2021-03-26  0.261910         NaN  0.703241  0.646248
# 2021-03-29  0.258794         NaN  0.702886  0.640762
# 2021-03-30  0.254371         NaN  0.701021  0.644120
# 2021-03-31  0.258229         NaN  0.703862  0.640526
#
# [1321 rows x 4 columns]

# %%
pos.sum('columns')
# Out:
# 2015-12-31    0.999029
# 2016-01-04    1.000423
# 2016-01-05    0.999374
# 2016-01-06    1.004562
# 2016-01-07    1.000215
#                 ...
# 2021-03-25    1.601772
# 2021-03-26    1.611398
# 2021-03-29    1.602442
# 2021-03-30    1.599511
# 2021-03-31    1.602617
# Length: 1321, dtype: float64

# %%
pos.sum('columns')*1000
# Out:
# 2015-12-31     999.029065
# 2016-01-04    1000.422502
# 2016-01-05     999.373592
# 2016-01-06    1004.562050
# 2016-01-07    1000.214817
#                  ...
# 2021-03-25    1601.772489
# 2021-03-26    1611.398192
# 2021-03-29    1602.441843
# 2021-03-30    1599.511313
# 2021-03-31    1602.617154
# Length: 1321, dtype: float64

# %% [markdown]
# Question 7

# %% [markdown]
# Question 8

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                          # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                       # Basic plot library.
plt.style.use('ggplot')

# %%
# start in 2005 since GLD not available earlier
PRICE = tiingo.get_dataframe(['SPY','GLD','TLT'], '2005-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
RET = PRICE.pct_change()
RET[:3]
# Out:
#                  SPY       GLD       TLT
# 2005-01-03       NaN       NaN       NaN
# 2005-01-04 -0.012219 -0.006509 -0.010480
# 2005-01-05 -0.006901 -0.001638  0.005352

# %%
RATES = quandl.get(['FRED/FEDFUNDS','FRED/DGS1','FRED/DGS5','FRED/DGS10','FRED/DGS30']) / 100
RATES.columns = ['FedFunds','Treasury_1', 'Treasury_5', 'Treasury_10', 'Treasury_30']
RATES
# Out:
#             FedFunds  Treasury_1  Treasury_5  Treasury_10  Treasury_30
# Date
# 1954-07-01    0.0080         NaN         NaN          NaN          NaN
# 1954-08-01    0.0122         NaN         NaN          NaN          NaN
# 1954-09-01    0.0107         NaN         NaN          NaN          NaN
# 1954-10-01    0.0085         NaN         NaN          NaN          NaN
# 1954-11-01    0.0083         NaN         NaN          NaN          NaN
# ...              ...         ...         ...          ...          ...
# 2021-04-05       NaN      0.0006      0.0094       0.0173       0.0236
# 2021-04-06       NaN      0.0006      0.0088       0.0167       0.0232
# 2021-04-07       NaN      0.0006      0.0087       0.0168       0.0235
# 2021-04-08       NaN      0.0005      0.0085       0.0164       0.0232
# 2021-04-09       NaN      0.0006      0.0087       0.0167       0.0234
#
# [15151 rows x 5 columns]

# %%
RET = RET.join(RATES.FedFunds.rename('MarginLoan'), how='outer')
RET['MarginLoan'] = RET.MarginLoan.ffill()/252 + 0.01/252           # Assume margin rate = fed funds rate + 100 bsp
RET = RET.dropna(subset=['SPY'])
RET
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2005-01-04 -0.012219 -0.006509 -0.010480    0.000130
# 2005-01-05 -0.006901 -0.001638  0.005352    0.000130
# 2005-01-06  0.005084 -0.012187  0.000680    0.000130
# 2005-01-07 -0.001433 -0.007355  0.002264    0.000130
# 2005-01-10  0.004728  0.002629  0.001581    0.000130
# ...              ...       ...       ...         ...
# 2021-04-06 -0.000591  0.008029  0.006793    0.000042
# 2021-04-07  0.001157 -0.002818 -0.006965    0.000042
# 2021-04-08  0.004747  0.010752  0.008255    0.000042
# 2021-04-09  0.007270 -0.007538 -0.003623    0.000042
# 2021-04-12  0.000365 -0.006064 -0.000436    0.000042
#
# [4095 rows x 4 columns]

# %%
def get_rebalance_dates(frequency):
    group = getattr(PRICE.index, frequency) 
    return PRICE[:1].index.union(PRICE.groupby([PRICE.index.year, group]).tail(1).index)



def run_backtest(frequency):   
    
    rebalance_dates = get_rebalance_dates(frequency) 

    portfolio_value = pd.Series(1,                      index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=RET.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=RET.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
        
        start_weights = select_weights(start_date)
        
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions  * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, weights, trades

# %%
def select_weights(date):
    
    if not RET[:date].empty:
        cov     = RET[['SPY','TLT','GLD']][:date][-200:].cov() * 252
        cov_inv = pd.DataFrame(np.linalg.inv(cov), columns=cov.columns, index=cov.index)
        
        w = cov_inv.sum() / cov_inv.sum().sum()
        
    else:
        w = pd.Series(1/3, index = ['SPY', 'TLT', 'GLD'])
    
    
    return w




min_vol, weights, trades = run_backtest('quarter')

# %%
min_vol
# Out:
# 2005-01-03    1.000000
# 2005-01-05    0.998938
# 2005-01-06    0.996793
# 2005-01-07    0.994658
# 2005-01-10    0.997618
#                 ...
# 2021-04-06    3.988361
# 2021-04-07    3.973473
# 2021-04-08    4.003084
# 2021-04-09    4.000661
# 2021-04-12    3.996841
# Length: 4095, dtype: float64

# %%
min_vol[:'2020']
# Out:
# 2005-01-03    1.000000
# 2005-01-05    0.998938
# 2005-01-06    0.996793
# 2005-01-07    0.994658
# 2005-01-10    0.997618
#                 ...
# 2020-12-24    4.172790
# 2020-12-28    4.180073
# 2020-12-29    4.179146
# 2020-12-30    4.193081
# 2020-12-31    4.205946
# Length: 4027, dtype: float64

# %%
min_vol[:'2020']*10000
# Out:
# 2005-01-03    10000.000000
# 2005-01-05     9989.380138
# 2005-01-06     9967.933225
# 2005-01-07     9946.579491
# 2005-01-10     9976.181659
#                   ...
# 2020-12-24    41727.896113
# 2020-12-28    41800.731922
# 2020-12-29    41791.455892
# 2020-12-30    41930.809628
# 2020-12-31    42059.459358
# Length: 4027, dtype: float64

# %% [markdown]
# Question 9

# %%
data = np.array([0.08, 0.04, 0.03])
  
meanx = pd.Series(data, index =['SPY', 'GLD', 'TLT'])
meanx
# Out:
# SPY    0.08
# GLD    0.04
# TLT    0.03
# dtype: float64

# %%
def get_rebalance_dates(frequency):
    group = getattr(PRICE.index, frequency) 
    return PRICE[:1].index.union(PRICE.groupby([PRICE.index.year, group]).tail(1).index)



def run_backtest(frequency):   
    
    rebalance_dates = get_rebalance_dates(frequency) 

    portfolio_value = pd.Series(1,                      index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=RET.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=RET.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
        
        start_weights = select_weights(start_date)
        
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions  * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, weights, trades

# %%
def select_weights(date):
    
    data = np.array([0.08, 0.04, 0.03])
  
    meanx = pd.Series(data, index =['SPY', 'GLD', 'TLT'])

    if not RET[:date].empty:
        cov     = RET[['SPY','TLT','GLD']][:date][-200:].cov() * 252
        cov_inv = pd.DataFrame(np.linalg.inv(cov), columns=cov.columns, index=cov.index)
        
        w = cov_inv.dot(meanx) /  cov_inv.dot(meanx).sum()
        
    else:
        w = pd.Series(1/3, index = ['SPY', 'TLT', 'GLD'])
    
    
    return w




maxSharpe, weights, trades = run_backtest('quarter')

# %%
maxSharpe
# Out:
# 2005-01-03    1.000000
# 2005-01-05    0.998938
# 2005-01-06    0.996793
# 2005-01-07    0.994658
# 2005-01-10    0.997618
#                 ...
# 2021-04-06    3.965917
# 2021-04-07    3.956189
# 2021-04-08    3.982250
# 2021-04-09    3.989425
# 2021-04-12    3.987865
# Length: 4095, dtype: float64

# %%
maxSharpe[:'2020']
# Out:
# 2005-01-03    1.000000
# 2005-01-05    0.998938
# 2005-01-06    0.996793
# 2005-01-07    0.994658
# 2005-01-10    0.997618
#                 ...
# 2020-12-24    4.054260
# 2020-12-28    4.066074
# 2020-12-29    4.063328
# 2020-12-30    4.074802
# 2020-12-31    4.088114
# Length: 4027, dtype: float64

# %%
maxSharpe[:'2020']*10000
# Out:
# 2005-01-03    10000.000000
# 2005-01-05     9989.380138
# 2005-01-06     9967.933225
# 2005-01-07     9946.579491
# 2005-01-10     9976.181659
#                   ...
# 2020-12-24    40542.596940
# 2020-12-28    40660.744301
# 2020-12-29    40633.282163
# 2020-12-30    40748.021974
# 2020-12-31    40881.135485
# Length: 4027, dtype: float64

# %% [markdown]
# Question 10

# %%
def get_rebalance_dates(frequency):
    group = getattr(PRICE.index, frequency) 
    return PRICE[:1].index.union(PRICE.groupby([PRICE.index.year, group]).tail(1).index)



def run_backtest(frequency):   
    
    rebalance_dates = get_rebalance_dates(frequency) 

    portfolio_value = pd.Series(1,                      index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=RET.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=RET.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
        
        start_weights = select_weights(start_date)
        
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions  * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, weights, trades

# %%
def select_weights(date):
    
    if not RET[:date].empty:
        cov     = RET[['SPY','TLT','GLD']][:date][-50:].cov() * 252
        cov_inv = pd.DataFrame(np.linalg.inv(cov), columns=cov.columns, index=cov.index)
        
        w = cov_inv.sum() / cov_inv.sum().sum()
        
    else:
        w = pd.Series(1/3, index = ['SPY', 'TLT', 'GLD'])
    
    
    return w




min_vol, weights, trades = run_backtest('month')

# %%
min_vol
# Out:
# 2005-01-03    1.000000
# 2005-01-05    0.998938
# 2005-01-06    0.996793
# 2005-01-07    0.994658
# 2005-01-10    0.997618
#                 ...
# 2021-04-06    4.106877
# 2021-04-07    4.091858
# 2021-04-08    4.125571
# 2021-04-09    4.116013
# 2021-04-12    4.107378
# Length: 4095, dtype: float64

# %%
weights
# Out:
#                  SPY       GLD       TLT  MarginLoan
# 2005-01-03       NaN       NaN       NaN         NaN
# 2005-01-05  0.331385  0.333141  0.335474         NaN
# 2005-01-06  0.333787  0.329789  0.336424         NaN
# 2005-01-07  0.334024  0.328067  0.337910         NaN
# 2005-01-10  0.334607  0.327953  0.337440         NaN
# ...              ...       ...       ...         ...
# 2021-04-06  0.238643  0.330241  0.431116         NaN
# 2021-04-07  0.239797  0.330519  0.429685         NaN
# 2021-04-08  0.238966  0.331342  0.429692         NaN
# 2021-04-09  0.241262  0.329609  0.429129         NaN
# 2021-04-12  0.241858  0.328299  0.429844         NaN
#
# [4095 rows x 4 columns]

# %%
w = weights.GLD['2018-5-21']
w
# Out:
# 0.28769987985775625

# %%
v = min_vol['2018-5-21']
v
# Out:
# 3.2469876154019275

# %%
w * v * 10000
# Out:
# 9341.57946850757

# %% [markdown]
# QUIZ 10

# %% [markdown]
# Question 1

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                                # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice

# %%
sectors = ['XLY', 'XLF', 'XLV', 'XLU']


PRICE = tiingo.get_dataframe(sectors, '1999-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
RET = PRICE.pct_change()

RATES = quandl.get(['FRED/FEDFUNDS','FRED/DGS1']) / 100
RATES.columns = ['FedFunds','Treasury_1']

# %%
RET
# Out:
#                  XLY       XLF       XLV       XLU
# 1999-01-04       NaN       NaN       NaN       NaN
# 1999-01-05  0.016943  0.009386  0.015420  0.012101
# 1999-01-06  0.028398  0.031699  0.016705  0.010296
# 1999-01-07 -0.001105  0.015158 -0.004481 -0.003616
# 1999-01-08  0.001106  0.006457  0.012003  0.005609
# ...              ...       ...       ...       ...
# 2021-04-13  0.010558 -0.009348  0.004150  0.011868
# 2021-04-14 -0.009834  0.006005 -0.000084  0.004417
# 2021-04-15  0.007166 -0.000853  0.017124  0.011071
# 2021-04-16  0.007732  0.007112  0.007464  0.008100
# 2021-04-19 -0.011230 -0.002825  0.000247 -0.005059
#
# [5609 rows x 4 columns]

# %%
pip install CVXOPT
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cvxopt
from cvxopt import matrix, solvers
solvers.options['show_progress'] = False

# %%
minimum_weight = 0.10

cov = RET['2005':'2010'].cov()


n = len(cov)
P = matrix(  cov.values )
q = matrix(  np.zeros(n) )
G = matrix( -np.identity(n) )
h = matrix( -np.ones(n)*minimum_weight)
A = matrix(  np.ones(n), (1,n))         
b = matrix(1.0)

sol = solvers.qp(P, q, G, h, A, b)

pd.Series({cov.index[i]:sol['x'][i] for i in range(n)})
# Out:
# XLY    0.101074
# XLF    0.100161
# XLV    0.593239
# XLU    0.205526
# dtype: float64

# %% [markdown]
# Question 2

# %%
def get_rebalance_dates(frequency, start_date):
    price = PRICE[PRICE.index>start_date]
    group = getattr(price.index, frequency) 
    return price[:1].index.union(price.groupby([price.index.year, group]).tail(1).index)



def compare_performance(t):
    t.add(1).cumprod().plot()
    t.add(1).cumprod().plot(logy=True)

    annual_returns = t[:'2020'].add(1).resample('A').prod().sub(1)
    r_annual_Tbill = RATES.Treasury_1.resample('A').first()

    x = pd.DataFrame()                        
    x['Average_returns']   = annual_returns.mean()
    x['Geometric_average'] = annual_returns.add(1).prod().pow(1/len(annual_returns)).sub(1)
    x['Risk_premium']      = annual_returns.sub(r_annual_Tbill, 'rows').dropna().mean()
    x['Volatility']        = t[:'2020'].std() * 252**0.5    
    x['Sharpe_ratio']      = x.Risk_premium / x.Volatility

    return x




def run_backtest(frequency, backtest_start='1900-1-1'):   
    
    rebalance_dates = get_rebalance_dates(frequency, backtest_start) 

    portfolio_value = pd.Series(1,                        index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(1, len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
                
        start_weights = select_weights(start_date)      # Call "select_weights()" function to get the weights
            
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions  * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, weights, trades

# %%
def select_weights(date):            
    return   pd.Series(1 / len(sectors), index = sectors)


ew, weights, trades = run_backtest('year','2006-1-1')
ew = ew.rename('EW')

ew
# Out:
# 2006-01-03    1.000000
# 2007-01-03    1.002631
# 2007-01-04    1.004246
# 2007-01-05    0.994533
# 2007-01-08    0.996310
#                 ...
# 2021-04-13    3.586665
# 2021-04-14    3.587286
# 2021-04-15    3.617032
# 2021-04-16    3.644483
# 2021-04-19    3.627250
# Name: EW, Length: 3599, dtype: float64

# %%
weights
# Out:
#                  XLY       XLF       XLV       XLU
# 2006-01-03       NaN       NaN       NaN       NaN
# 2007-01-03  0.249993  0.250566  0.249418  0.250023
# 2007-01-04  0.249526  0.249350  0.251842  0.249282
# 2007-01-05  0.250262  0.249664  0.252876  0.247198
# 2007-01-08  0.250207  0.250448  0.252724  0.246621
# ...              ...       ...       ...       ...
# 2021-04-13  0.252818  0.270188  0.237800  0.239194
# 2021-04-14  0.250288  0.271764  0.237739  0.240209
# 2021-04-15  0.250009  0.269299  0.239821  0.240871
# 2021-04-16  0.250044  0.269172  0.239791  0.240993
# 2021-04-19  0.248411  0.269686  0.240990  0.240913
#
# [3599 rows x 4 columns]

# %%
ew['2016-06']*4000
# Out:
# 2016-06-01    7354.357247
# 2016-06-02    7391.505670
# 2016-06-03    7380.542980
# 2016-06-06    7402.238903
# 2016-06-07    7388.033124
# 2016-06-08    7410.059153
# 2016-06-09    7408.035639
# 2016-06-10    7348.010982
# 2016-06-13    7309.860928
# 2016-06-14    7293.804816
# 2016-06-15    7275.827774
# 2016-06-16    7305.263172
# 2016-06-17    7290.452498
# 2016-06-20    7319.109446
# 2016-06-21    7321.596811
# 2016-06-22    7312.715524
# 2016-06-23    7394.694425
# 2016-06-24    7193.734774
# 2016-06-27    7110.089483
# 2016-06-28    7225.889914
# 2016-06-29    7329.958522
# 2016-06-30    7431.914882
# Name: EW, dtype: float64

# %% [markdown]
# Question 3

# %%
weights['2015-12':'2016-1-5']
# Out:
#                  XLY       XLF       XLV       XLU
# 2015-12-01  0.274293  0.244155  0.256324  0.225228
# 2015-12-02  0.275323  0.244335  0.257356  0.222986
# 2015-12-03  0.275429  0.244127  0.255673  0.224770
# 2015-12-04  0.274984  0.245450  0.256312  0.223253
# 2015-12-07  0.274894  0.244114  0.255871  0.225121
# 2015-12-08  0.275080  0.241913  0.257382  0.225626
# 2015-12-09  0.273990  0.241252  0.257065  0.227693
# 2015-12-10  0.275115  0.241626  0.259174  0.224085
# 2015-12-11  0.273229  0.240137  0.259522  0.227113
# 2015-12-14  0.273330  0.239511  0.259985  0.227175
# 2015-12-15  0.271497  0.242145  0.260173  0.226185
# 2015-12-16  0.271276  0.241825  0.259000  0.227899
# 2015-12-17  0.269571  0.240827  0.258868  0.230734
# 2015-12-18  0.269994  0.238529  0.259593  0.231884
# 2015-12-21  0.269761  0.239468  0.260411  0.230359
# 2015-12-22  0.269603  0.239806  0.260107  0.230484
# 2015-12-23  0.268150  0.240100  0.260158  0.231591
# ...

# %% [markdown]
# Question 4

# %% [markdown]
# first and fourth

# %% [markdown]
# Question 5

# %%
d = { 'a':0.2, 'b':0.8 }
x = pd.Series (data = d, index = ['a','b'])

y = pd.Series (-1, index = ['c'])

print(x)
print(y)
# Out:
# a    0.2
# b    0.8
# dtype: float64
# c   -1
# dtype: int64

# %%
x.multiply(2).append(y)
# Out:
# a    0.4
# b    1.6
# c   -1.0
# dtype: float64

# %%
x.multiply(2) + y
# Out:
# a   NaN
# b   NaN
# c   NaN
# dtype: float64

# %%
(2*x) + y
# Out:
# a   NaN
# b   NaN
# c   NaN
# dtype: float64

# %%
x.multiply(2).join(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-2759c07e43ad> in <module>
# ----> 1 x.multiply(2).join(y)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'join'

# %%
x.multiply(2).concat(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-5e5d44416223> in <module>
# ----> 1 x.multiply(2).concat(y)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'concat'

# %%
pd.concat([2*x,y])
# Out:
# a    0.4
# b    1.6
# c   -1.0
# dtype: float64

# %% [markdown]
# Question 6

# %%
annual_returns = RET['2005':'2019'].add(1).resample('A').prod().sub(1)

x = pd.DataFrame()                        

x['Geometric_average'] = annual_returns.add(1).prod().pow(1/len(annual_returns)).sub(1)
x
# Out:
#      Geometric_average
# XLY           0.103656
# XLF           0.035710
# XLV           0.103303
# XLU           0.096295

# %% [markdown]
# Question 7

# %%
d = { 'XLU': 50/170, 'XLF':80/170, 'XLV':40/180 }
weights = pd.Series (data = d, index = ['XLU','XLF','XLV'])
weights
# Out:
# XLU    0.294118
# XLF    0.470588
# XLV    0.222222
# dtype: float64

# %%
annual_returns = RET[['XLU','XLF','XLV']]['2010':'2020'].add(1).resample('A').prod().sub(1)
    
annual_returns.mean()
# Out:
# XLU    0.110294
# XLF    0.121464
# XLV    0.150481
# dtype: float64

# %%
ans = annual_returns.mean() * weights
ans.sum()
# Out:
# 0.12303909158876897

# %%
annual_returns2 = RET[['XLU','XLF','XLV']]['2010':'2020'].add(1).resample('A').prod().sub(1).multiply(weights)
    
annual_returns2.mean().sum()
# Out:
# 0.12303909158876898

# %% [markdown]
# Question 8

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                                # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice

# %%
sectors = ['XLY', 'XLF', 'XLV', 'XLU']


PRICE = tiingo.get_dataframe(sectors, '1999-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
RET = PRICE.pct_change()

RATES = quandl.get(['FRED/FEDFUNDS','FRED/DGS1']) / 100
RATES.columns = ['FedFunds','Treasury_1']

# %%
spy = tiingo.get_dataframe(['SPY'], '1999-1-1', metric_name='adjClose')
spy.index = pd.to_datetime(spy.index).tz_convert(None)
spy[-3:]
# Out:
#                SPY
# 2021-04-15  415.87
# 2021-04-16  417.26
# 2021-04-19  415.21

# %%
len(sectors)
# Out:
# 4

# %%
pip install CVXOPT
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_rebalance_dates(frequency, start_date):
    price = PRICE[PRICE.index>start_date]
    group = getattr(price.index, frequency) 
    return price[:1].index.union(price.groupby([price.index.year, group]).tail(1).index)



def compare_performance(t):
    t.add(1).cumprod().plot()
    t.add(1).cumprod().plot(logy=True)

    annual_returns = t[:'2015'].add(1).resample('A').prod().sub(1)
    r_annual_Tbill = RATES.Treasury_1.resample('A').first()

    x = pd.DataFrame()                        
    x['Average_returns']   = annual_returns.mean()
    x['Geometric_average'] = annual_returns.add(1).prod().pow(1/len(annual_returns)).sub(1)
    x['Risk_premium']      = annual_returns.sub(r_annual_Tbill, 'rows').dropna().mean()
    x['Volatility']        = t[:'2015'].std() * 252**0.5    
    x['Sharpe_ratio']      = x.Risk_premium / x.Volatility

    return x




def run_backtest(frequency, backtest_start='1900-1-1'):   
    
    rebalance_dates = get_rebalance_dates(frequency, backtest_start) 

    portfolio_value = pd.Series(1,                        index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(1, len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
                
        start_weights = select_weights(start_date)      # Call "select_weights()" function to get the weights
            
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions  * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value.pct_change(), weights, trades

# %%
def select_weights(date):   
    
    minimum_weight = 0 
    cov = RET[:date][-250:].cov()

    n = len(cov)
    P = matrix( cov.values )
    q = matrix( np.zeros(n) )
    G = matrix( -np.identity(n) ) 
    h = matrix( -np.ones(n)*minimum_weight)
    A = matrix( np.ones(n), (1,n)) 
    b = matrix(1.0)

    sol = solvers.qp(P, q, G, h, A, b)

    w = pd.Series({cov.index[i]:sol['x'][i] for i in range(n)})
    
    return w


mv_cvxopt, weights, trades = run_backtest('quarter', '2000-1-1')
mv_cvxopt = mv_cvxopt.rename('MinVol_cvxopt')

t = pd.DataFrame(mv_cvxopt).join(spy.pct_change())
compare_performance(t)
# Out:
#                Average_returns  Geometric_average  Risk_premium  Volatility  \
# MinVol_cvxopt         0.065850           0.055911      0.045013    0.165255
# SPY                   0.054971           0.037486      0.034133    0.200753
#
#                Sharpe_ratio
# MinVol_cvxopt      0.272382
# SPY                0.170026

# %% [markdown]
# Question 9

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                                # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice

# %%
sectors = ['XLY', 'XLF', 'XLV', 'XLU']

PRICE = tiingo.get_dataframe(sectors, '1999-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)

RATES = quandl.get(['FRED/FEDFUNDS','FRED/DGS1']) / 100
RATES.columns = ['FedFunds','Treasury_1']


RET = PRICE.pct_change()
RET = RET.join(RATES.FedFunds.rename('MarginLoan'), how='outer')
RET['MarginLoan'] = RET.MarginLoan.ffill()/252 + 0.01/252           # Assume margin rate = fed funds rate + 100 bsp
RET = RET.dropna(subset=['XLY'])


RET.add(1).cumprod().plot(logy=True)

# %%
len(sectors)
# Out:
# 4

# %%
pip install CVXOPT
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_rebalance_dates(frequency, start_date):
    price = PRICE[PRICE.index>start_date]
    group = getattr(price.index, frequency) 
    return price[:1].index.union(price.groupby([price.index.year, group]).tail(1).index)



def compare_performance(t):
    t.add(1).cumprod().plot()
    t.add(1).cumprod().plot(logy=True)

    annual_returns = t[:'2015'].add(1).resample('A').prod().sub(1)
    r_annual_Tbill = RATES.Treasury_1.resample('A').first()

    x = pd.DataFrame()                        
    x['Average_returns']   = annual_returns.mean()
    x['Geometric_average'] = annual_returns.add(1).prod().pow(1/len(annual_returns)).sub(1)
    x['Risk_premium']      = annual_returns.sub(r_annual_Tbill, 'rows').dropna().mean()
    x['Volatility']        = t[:'2015'].std() * 252**0.5    
    x['Sharpe_ratio']      = x.Risk_premium / x.Volatility

    return x




def run_backtest(frequency, backtest_start='1900-1-1'):   
    
    rebalance_dates = get_rebalance_dates(frequency, backtest_start) 

    portfolio_value = pd.Series(1,                        index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(1, len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
                
        start_weights = select_weights(start_date)      # Call "select_weights()" function to get the weights
            
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions  * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, weights, trades

# %%
def select_weights(date):   
    
    minimum_weight = 0 
    cov = RET[['XLY','XLF','XLV','XLU']][:date][-250:].cov()

    n = len(cov)
    P = matrix( cov.values )
    q = matrix( np.zeros(n) )
    G = matrix( -np.identity(n) ) 
    h = matrix( -np.ones(n)*minimum_weight)
    A = matrix( np.ones(n), (1,n)) 
    b = matrix(1.0)

    sol = solvers.qp(P, q, G, h, A, b)

    w = pd.Series({cov.index[i]:sol['x'][i] for i in range(n)})
    w = w.multiply(1.4).append(pd.Series({'MarginLoan':-0.4}))
    
    
    return w


mv_cvxopt, weights, trades = run_backtest('quarter', '2000-1-1')
mv_cvxopt = mv_cvxopt.rename('MinVol_cvxopt')

mv_cvxopt['2015']*1000
# Out:
# 2015-01-02    2659.562117
# 2015-01-05    2597.586758
# 2015-01-06    2572.236098
# 2015-01-07    2614.171581
# 2015-01-08    2656.176788
#                  ...
# 2015-12-24    2646.682495
# 2015-12-28    2652.503546
# 2015-12-29    2684.933378
# 2015-12-30    2666.819112
# 2015-12-31    2629.018333
# Name: MinVol_cvxopt, Length: 252, dtype: float64

# %% [markdown]
# Question 10

# %%
sectors = ['XLY', 'XLF', 'XLV', 'XLU']


PRICE = tiingo.get_dataframe(sectors, '1999-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)

RET = PRICE.pct_change()

# %%
RET['2000']
# Out:
#                  XLY       XLF       XLV       XLU
# 2000-01-03 -0.030264 -0.037442 -0.019100 -0.024520
# 2000-01-04 -0.029880 -0.043706 -0.022772 -0.029872
# 2000-01-05 -0.003080  0.000457 -0.002702  0.021404
# 2000-01-06  0.002060  0.035176 -0.003048  0.001838
# 2000-01-07  0.046934  0.016328  0.012228  0.008440
# ...              ...       ...       ...       ...
# 2000-12-22  0.017020  0.008034  0.016981  0.015788
# 2000-12-26 -0.019184  0.018018  0.001855  0.028287
# 2000-12-27  0.048273  0.006127  0.003333  0.000000
# 2000-12-28  0.012306  0.010149  0.017350 -0.008162
# 2000-12-29  0.003529 -0.012056 -0.011248  0.011582
#
# [252 rows x 4 columns]

# %%
x = pd.DataFrame()

x['Inverse_Volatility'] = 1 / (RET['2000'].std() * 252**0.5)
 
x
# Out:
#      Inverse_Volatility
# XLY            3.122880
# XLF            3.007330
# XLV            3.809376
# XLU            4.359258

# %%
y = (x['Inverse_Volatility'].sum())
y
# Out:
# 14.298843872912304

# %%
x['weight'] = x['Inverse_Volatility'] / y
x
# Out:
#      Inverse_Volatility    weight
# XLY            3.122880  0.218401
# XLF            3.007330  0.210320
# XLV            3.809376  0.266412
# XLU            4.359258  0.304868

# %%
x['weight'].sum()
# Out:
# 1.0

# %% [markdown]
# Question 11

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                                # To access websites.

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')

# %%
sectors = ['XLY', 'XLF', 'XLV', 'XLU']


PRICE = tiingo.get_dataframe(sectors, '1999-1-1', metric_name='adjClose')
PRICE.index = pd.to_datetime(PRICE.index).tz_convert(None)
RET = PRICE.pct_change()

RATES = quandl.get(['FRED/FEDFUNDS','FRED/DGS1']) / 100
RATES.columns = ['FedFunds','Treasury_1']

# %%
def get_rebalance_dates(frequency, start_date):
    price = PRICE[PRICE.index>start_date]
    group = getattr(price.index, frequency) 
    return price[:1].index.union(price.groupby([price.index.year, group]).tail(1).index)



def compare_performance(t):
    t.add(1).cumprod().plot()
    t.add(1).cumprod().plot(logy=True)

    annual_returns = t[:'2020'].add(1).resample('A').prod().sub(1)
    r_annual_Tbill = RATES.Treasury_1.resample('A').first()

    x = pd.DataFrame()                        
    x['Average_returns']   = annual_returns.mean()
    x['Geometric_average'] = annual_returns.add(1).prod().pow(1/len(annual_returns)).sub(1)
    x['Risk_premium']      = annual_returns.sub(r_annual_Tbill, 'rows').dropna().mean()
    x['Volatility']        = t[:'2020'].std() * 252**0.5    
    x['Sharpe_ratio']      = x.Risk_premium / x.Volatility

    return x




def run_backtest(frequency, backtest_start='1900-1-1'):   
    
    rebalance_dates = get_rebalance_dates(frequency, backtest_start) 

    portfolio_value = pd.Series(1,                        index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(1, len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
                
        start_weights = select_weights(start_date)      # Call "select_weights()" function to get the weights
            
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions  * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, weights, trades

# %%
def select_weights(date):   
    
    x = 1 / (RET[:date][-30:].std() * 252**0.5)
    y = x.sum()
    
    w = x/y
    
    return w


portfolio_value, weights, trades = run_backtest('month', '2000-1-1')

portfolio_value
# Out:
# 2000-01-03    1.000000
# 2000-02-01    1.012007
# 2000-02-02    1.011378
# 2000-02-03    1.012519
# 2000-02-04    1.008419
#                 ...
# 2021-04-13    5.646599
# 2021-04-14    5.649716
# 2021-04-15    5.704465
# 2021-04-16    5.747815
# 2021-04-19    5.725115
# Length: 5338, dtype: float64

# %%
portfolio_value['2020']*5000
# Out:
# 2020-01-02    23176.089007
# 2020-01-03    23037.265206
# 2020-01-06    23093.767195
# 2020-01-07    23031.822855
# 2020-01-08    23117.155669
#                   ...
# 2020-12-24    25231.428939
# 2020-12-28    25380.441601
# 2020-12-29    25399.439534
# 2020-12-30    25495.640773
# 2020-12-31    25731.594430
# Length: 253, dtype: float64

# %% [markdown]
# QUIZ 11

# %% [markdown]
# Question 1

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                                # To access websites.

import os

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice

# %%
y = pd.read_csv('data/sec/merged/2015q4.csv', parse_dates=['filed','ddate'])

# %%
def get_items_from_SEC_files(tags, filename=None):                # Function input: list of tags, optional filename.

    directory = 'data/sec/merged/'                                # Read data from here.
    filenames = [filename] if filename else os.listdir(directory) # Supplied filename or all files in "merged" directory.
    filenames = [f for f in filenames if not f.startswith(".")]   # Exclude hidden files from file list.

    results   = {t:pd.DataFrame() for t in tags}                  # Dictionary of tables (1 table for each tag)

    for filename in sorted(filenames):                            # Loop over all files.
        print(filename)
        data = pd.read_csv(directory+filename, parse_dates=['filed','ddate'])  # Read the file.
        
        for t in tags:                                            # Loop over all tags.
            item  = data[data.tag==t]                             # Select all data for this tag.
            short = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,False]) # Samllest qrts.
            long  = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,True])  # Largest  qtrs.
            short = short.groupby(['cik','filed']).last()[['value','qtrs']]     # One value for each firm and filing.
            long  = long .groupby(['cik','filed']).last()[['value','qtrs']]     
            short_long = short.join(long, lsuffix='_shortest', rsuffix='_longest') # Put shortest and longest next to each other.
            results[t] = results[t].append( short_long )  
                        
    for t in tags:                                                # Now sort all tables by filing date.
        if not results[t].empty: results[t] = results[t].sort_index(level='filed')            

    return results

# %%
x = get_items_from_SEC_files(['CashAndCashEquivalentsAtCarryingValue'], '2015q4.csv')
# Out:
# 2015q4.csv

# %%
x
# Out:
# {'CashAndCashEquivalentsAtCarryingValue':                     value_shortest  qtrs_shortest  value_longest  qtrs_longest
#  cik     filed
#  7623    2015-10-01        643540.0              0       643540.0             0
#  10329   2015-10-01      20600000.0              0     20600000.0             0
#  704172  2015-10-01         10654.0              0        10654.0             0
#  730255  2015-10-01     100098000.0              0    100098000.0             0
#  824416  2015-10-01          7886.0              0         7886.0             0
#  ...                            ...            ...            ...           ...
#  1628104 2015-12-30          2315.0              0         2315.0             0
#  1354591 2015-12-31            55.0              0           55.0             0
#  1451433 2015-12-31         56898.0              0        56898.0             0
#  1515620 2015-12-31             NaN              0            NaN             0
# ...

# %%
y
# Out:
#             cik     sic countryinc  \
# 0          3545   100.0         US
# 1          3545   100.0         US
# 2          3545   100.0         US
# 3          3545   100.0         US
# 4          3545   100.0         US
# ...         ...     ...        ...
# 2226063  801348  6500.0         US
# 2226064  801348  6500.0         US
# 2226065  801348  6500.0         US
# 2226066  801348  6500.0         US
# 2226067  801348  6500.0         US
#
#                                                        tag      filed  \
# 0                                   AccountsPayableCurrent 2015-12-10
# 1                                   AccountsPayableCurrent 2015-12-10
# 2                             AccountsReceivableNetCurrent 2015-12-10
# 3                             AccountsReceivableNetCurrent 2015-12-10
# 4                                AccruedLiabilitiesCurrent 2015-12-10
# ...                                                    ...        ...
# ...

# %% [markdown]
# Question 2

# %%
tags = [ 'NetIncomeLossAvailableToCommonStockholdersBasic',  'NetIncomeLoss', 'ProfitLoss' ]

# %%
items = get_items_from_SEC_files(tags)
# Out:
# 2009q1.csv
# 2009q2.csv
# 2009q3.csv
# 2009q4.csv
# 2010q1.csv
# 2010q2.csv
# 2010q3.csv
# 2010q4.csv
# 2011q1.csv
# 2011q2.csv
# 2011q3.csv
# 2011q4.csv
# 2012q1.csv
# 2012q2.csv
# 2012q3.csv
# 2012q4.csv
# 2013q1.csv
# 2013q2.csv
# 2013q3.csv
# 2013q4.csv
# 2014q1.csv
# 2014q2.csv
# 2014q3.csv
# 2014q4.csv
# 2015q1.csv
# 2015q2.csv
# 2015q3.csv
# 2015q4.csv
# 2016q1.csv
# 2016q2.csv
# 2016q3.csv
# 2016q4.csv
# 2017q1.csv
# 2017q2.csv
# 2017q3.csv
# 2017q4.csv
# 2018q1.csv
# 2018q2.csv
# 2018q3.csv
# 2018q4.csv
# 2019q1.csv
# 2019q2.csv
# 2019q3.csv
# 2019q4.csv
# 2020_10.csv
# 2020_11.csv
# 2020_12.csv
# 2020q1.csv
# 2020q2.csv
# 2020q3.csv
# 2021_01.csv
# 2021_02.csv
# 2021_03.csv

# %%
cik = symbols[symbols.ticker=='XOM'].index[0]

t = [items[tag].loc[cik].value_shortest.rename(tag) for tag in tags if cik in items[tag].index]
pd.concat(t, 'columns')
# Out:
#             NetIncomeLoss    ProfitLoss
# filed
# 2009-08-05   3.950000e+09  3.946000e+09
# 2009-11-05   4.730000e+09  4.871000e+09
# 2010-02-26   1.928000e+10  1.965800e+10
# 2010-05-06   6.300000e+09  6.575000e+09
# 2010-08-04   7.560000e+09  7.746000e+09
# 2010-11-03   7.350000e+09  7.561000e+09
# 2011-02-25   3.046000e+10  3.139800e+10
# 2011-05-05   1.065000e+10  1.091300e+10
# 2011-08-04   1.068000e+10  1.089800e+10
# 2011-11-03   1.033000e+10  1.067100e+10
# 2012-02-24   4.106000e+10  4.220600e+10
# 2012-05-03   9.450000e+09  9.799000e+09
# 2012-08-02   1.591000e+10  1.765400e+10
# 2012-11-06   9.570000e+09  9.926000e+09
# 2013-02-27   4.488000e+10  4.768100e+10
# 2013-05-02   9.500000e+09  9.761000e+09
# 2013-08-06   6.860000e+09  6.975000e+09
# 2013-11-05   7.870000e+09  8.069000e+09
# 2014-02-26   3.258000e+10  3.344800e+10
# 2014-05-07   9.100000e+09  9.370000e+09
# 2014-08-06   8.780000e+09  9.117000e+09
# 2014-11-05   8.070000e+09  8.346000e+09
# ...

# %% [markdown]
# Question 3

# %%
def combine_items(tags, items):
    result = items[tags[0]]
    for tag in tags[1:]:  result = result.combine_first( items[tag] )
    return result

# %%
tags = ['NetIncomeLossAvailableToCommonStockholdersBasic','NetIncomeLoss','ProfitLoss']

items['earnings'] = combine_items(tags, items)

# %%
cik = symbols[symbols.ticker=='WMT'].index[0]
cik
# Out:
# 104169

# %%
items['earnings'].loc[cik]
# Out:
#             value_shortest qtrs_shortest  value_longest qtrs_longest
# filed
# 2009-09-09    3.442000e+09             1   6.464000e+09            2
# 2009-12-08    3.239000e+09             1   9.703000e+09            3
# 2010-03-30    1.433500e+10             4   1.433500e+10            4
# 2010-06-04    3.324000e+09             1   3.324000e+09            1
# 2010-09-01    3.596000e+09             1   6.897000e+09            2
# 2010-12-06    3.436000e+09             1   1.033300e+10            3
# 2011-03-30    6.056000e+09             1   1.638900e+10            4
# 2011-06-03    3.399000e+09             1   3.399000e+09            1
# 2011-09-01    3.801000e+09             1   7.200000e+09            2
# 2011-12-08    3.336000e+09             1   1.053600e+10            3
# 2012-03-27    5.163000e+09             1   1.569900e+10            4
# 2012-06-01    3.742000e+09             1   3.742000e+09            1
# ...

# %% [markdown]
# Question 4

# %%
def calculate_quarterly_annual_values(item):                        # item: table with shortest and longest values and quarters.
    result           = pd.DataFrame()                               # Results go here.
    all_firms        = item.index.get_level_values('cik').unique()  # All CIKs.
    all_filing_dates = pd.read_csv('data/sec/dates/filing_dates.csv', index_col='cik', parse_dates=['filed'])
    
    for cik in all_firms:                                           # Loop over all firms.  
        filing_dates = pd.Series(all_filing_dates.filed[cik])       # All filing dates for this firm.

        # Quarterly values:
        valuesQ = item.loc[cik].value_shortest.reindex(filing_dates) # Values with shortest reported quarters.
        qtrsQ   = item.loc[cik].qtrs_shortest.astype(int)           # Number of quarters for each value.
        for date,q in qtrsQ[qtrsQ>1].iteritems():                   # Loop over all dates with > 1 quarters. 
            previous_values = valuesQ[:date][-q:-1]                 # Example: for q=3 we need to subtract 2 previous quarters.            
            if len(previous_values) == q-1:                         # If all previous values available.
                valuesQ[date] -= previous_values.sum(skipna=False)  # Subtract previous values to get quarterly value.
            else:
                valuesQ[date]  = np.nan                  

        # Annual values:
        valuesA = item.loc[cik].value_longest.reindex(filing_dates) # Values with longest reported quarters.
        qtrsA   = item.loc[cik].qtrs_longest.astype(int)            # Number of quarters for each value.
        for date,q in qtrsA[qtrsA<4].iteritems():                   # Loop over all dates with < 4 quarters. 
            previous_values = valuesQ[:date][-4:-q]                 # Example: for q=2 we need to add quarters -3 and -4.
            if len(previous_values) == 4-q:                         # If all previous data available.     
                valuesA[date] += previous_values.sum(skipna=False)  # Add previous values to get annual values.
            else:
                valuesA[date]  = np.nan        
        
        result = result.append( pd.DataFrame({'cik':cik, 'filed':filing_dates, 'valueQ':valuesQ.values, 'valueA':valuesA.values}) )

    return result.set_index(['cik','filed'])                        # Return a table with columns 'valueQ' and 'valueA'.



earnings = calculate_quarterly_annual_values(items['earnings'])

# %%
earnings
# Out:
#                         valueQ      valueA
# cik     filed
# 1750    2010-09-23  13674000.0         NaN
#         2010-12-21  16814000.0         NaN
#         2011-03-22  17918000.0         NaN
#         2011-07-13  21420000.0  69826000.0
#         2011-09-23  16053000.0  72205000.0
# ...                        ...         ...
# 1835378 2021-03-29     -5000.0         NaN
# 1835385 2021-03-26    390728.0         NaN
# 1835416 2021-03-31   -195860.0         NaN
# 1836259 2021-03-30      -567.0         NaN
# 1836981 2021-03-31    -34096.0         NaN
#
# [254711 rows x 2 columns]

# %%
earnings[earnings.valueQ == earnings.valueQ.min()]
# Out:
#                           valueQ        valueA
# cik     filed
# 1067983 2020-05-04 -4.974600e+10  1.001000e+10

# %%
earnings.idxmin()
# Out:
# valueQ    (1067983, 2020-05-04 00:00:00)
# valueA     (310522, 2010-02-26 00:00:00)
# dtype: object

# %%
symbols.loc[1067983]
# Out:
# ticker                            BRK-A
# title            BERKSHIRE HATHAWAY INC
# exchange                           NYSE
# assetType                         Stock
# priceCurrency                       USD
# startDate                    1980-03-17
# endDate                      2021-04-16
# Name: 1067983, dtype: object

# %% [markdown]
# Question 5

# %%
trading_days = pd.to_datetime( tiingo.get_dataframe('SPY','2009-04-15').index ).tz_convert(None)
trading_days
# Out:
# DatetimeIndex(['2009-04-15', '2009-04-16', '2009-04-17', '2009-04-20',
#                '2009-04-21', '2009-04-22', '2009-04-23', '2009-04-24',
#                '2009-04-27', '2009-04-28',
#                ...
#                '2021-04-13', '2021-04-14', '2021-04-15', '2021-04-16',
#                '2021-04-19', '2021-04-20', '2021-04-21', '2021-04-22',
#                '2021-04-23', '2021-04-26'],
#               dtype='datetime64[ns]', name='date', length=3029, freq=None)

# %%
def ffill_values(item, dates):                                          
    data = item.unstack('cik')
    data = data.reindex(dates.union(data.index)).sort_index()           # Add specified dates to index.
    filing_dates = pd.read_csv('data/sec/dates/filing_dates.csv', index_col='cik', parse_dates=['filed']).filed
    last_filing_date_all_firms = filing_dates.max()                     # Most recent date where at least 1 firm filed.
     
    for cik in data.columns:                                            # Loop over all firms.
        last_filing_date      = pd.Series(filing_dates[cik]).iloc[-1]   # Last date where this firm filed
        days_since_last_filed = (last_filing_date_all_firms - last_filing_date).days
        last_date_this_firm   = dates[-1] if days_since_last_filed < 120 else last_filing_date
        data.loc[:last_date_this_firm, cik].ffill(inplace=True)         # Forward fill all the values.

    return data.loc[dates]                                              # Return only specified dates.

# %%
earnings
# Out:
#                         valueQ      valueA
# cik     filed
# 1750    2010-09-23  13674000.0         NaN
#         2010-12-21  16814000.0         NaN
#         2011-03-22  17918000.0         NaN
#         2011-07-13  21420000.0  69826000.0
#         2011-09-23  16053000.0  72205000.0
# ...                        ...         ...
# 1835378 2021-03-29     -5000.0         NaN
# 1835385 2021-03-26    390728.0         NaN
# 1835416 2021-03-31   -195860.0         NaN
# 1836259 2021-03-30      -567.0         NaN
# 1836981 2021-03-31    -34096.0         NaN
#
# [254711 rows x 2 columns]

# %%
earnings.unstack('cik').valueQ
# Out:
# cik         1750     1800     1961     2034       2098     2178     2186     \
# filed
# 2009-04-15      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# 2009-04-23      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# 2009-04-27      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# 2009-04-29      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# 2009-04-30      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# ...             ...      ...      ...      ...        ...      ...      ...
# 2021-03-25      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# 2021-03-26      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# 2021-03-29      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# 2021-03-30      NaN      NaN      NaN      NaN        NaN      NaN      NaN
# 2021-03-31      NaN      NaN      NaN      NaN  2043766.0      NaN      NaN
#
# ...

# %%
ffill_values( earnings.valueQ, trading_days )
# Out:
# cik            1750          1800      1961     2034       2098       2178     \
# date
# 2009-04-15         NaN           NaN       NaN      NaN        NaN        NaN
# 2009-04-16         NaN           NaN       NaN      NaN        NaN        NaN
# 2009-04-17         NaN           NaN       NaN      NaN        NaN        NaN
# 2009-04-20         NaN           NaN       NaN      NaN        NaN        NaN
# 2009-04-21         NaN           NaN       NaN      NaN        NaN        NaN
# ...                ...           ...       ...      ...        ...        ...
# 2021-04-20  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
# 2021-04-21  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
# 2021-04-22  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
# 2021-04-23  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
# 2021-04-26  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
#
# ...

# %% [markdown]
# Question 6

# %%
x = ffill_values(earnings.valueQ, trading_days)
x
# Out:
# cik            1750          1800      1961     2034       2098       2178     \
# date
# 2009-04-15         NaN           NaN       NaN      NaN        NaN        NaN
# 2009-04-16         NaN           NaN       NaN      NaN        NaN        NaN
# 2009-04-17         NaN           NaN       NaN      NaN        NaN        NaN
# 2009-04-20         NaN           NaN       NaN      NaN        NaN        NaN
# 2009-04-21         NaN           NaN       NaN      NaN        NaN        NaN
# ...                ...           ...       ...      ...        ...        ...
# 2021-04-20  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
# 2021-04-21  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
# 2021-04-22  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
# 2021-04-23  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
# 2021-04-26  28100000.0  2.152000e+09 -376259.0      NaN  2043766.0  5846000.0
#
# ...

# %%
x['2018'].iloc[-1].nlargest(5).sum()/(10**9)
# Out:
# 58.629

# %% [markdown]
# Question 7

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                                # To access websites.

import os

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice

# %%
PRICE = pd.read_csv('data/tiingo/close.csv', index_col = 'date', parse_dates = ['date'])
PRICE
# Out:
#               AIR     ABT    WDDD      ACU     AE    BKTI    AMD    AEM  \
# date
# 2009-04-15  14.43   42.66  0.1700   7.4300  14.65  0.6400   3.44  49.32
# 2009-04-16  15.04   42.69  0.1700   7.6000  14.84  0.6300   3.57  45.73
# 2009-04-17  15.17   43.89  0.1700   7.2000  15.00  0.5500   3.56  43.65
# 2009-04-20  14.01   44.09  0.1700   7.3800  14.50  0.5598   3.31  46.97
# 2009-04-21  14.66   44.37  0.1700   7.3900  14.50  0.5600   3.36  45.53
# ...           ...     ...     ...      ...    ...     ...    ...    ...
# 2021-04-12  40.92  121.04  0.3925  38.6900  26.00  4.6400  78.58  60.12
# 2021-04-13  40.23  123.01  0.3850  38.7501  26.34  4.5100  80.19  61.25
# 2021-04-14  41.08  121.50  0.3900  38.3057  26.59  4.6800  78.55  60.80
# 2021-04-15  40.76  123.94  0.4450  37.1000  27.02  4.5800  83.01  63.26
# 2021-04-16  40.65  124.35  0.4000  37.8350  27.00  4.5400  82.15  64.58
#
#                APD    AKZOF  ...   KVSB    TIOAU   MSDAU   GGPIU   NECB  \
# ...

# %%
VOLUME = pd.read_csv('data/tiingo/volume.csv', index_col='date', parse_dates=['date'])
VOLUME[-3:]
# Out:
#                AIR      ABT      WDDD    ACU     AE   BKTI       AMD      AEM  \
# date
# 2021-04-14  158866  4726734   23094.0   2274  11105  35817  34263832  2058916
# 2021-04-15  151706  4510894  186359.0  32977  16172  15322  68942819  2106932
# 2021-04-16  137437  6243068  143826.0  26614   7406  10587  47280570  1558861
#
#                 APD  AKZOF  ...      KVSB     TIOAU     MSDAU      GGPIU  \
# date                        ...
# 2021-04-14   631742    0.0  ...  136226.0  373794.0   30383.0  3554064.0
# 2021-04-15   778193  690.0  ...   16090.0   12986.0   80354.0   904483.0
# 2021-04-16  1013546  200.0  ...   19720.0    3553.0  186007.0   270444.0
#
#              NECB      HITIF     AYRWF  OUTR  ABCO  NHLDW
# date
# 2021-04-14    0.0  4040925.0   56030.0   NaN   NaN    NaN
# 2021-04-15  475.0  5853973.0   97611.0   NaN   NaN    NaN
# 2021-04-16  390.0  3057846.0  106705.0   NaN   NaN    NaN
#
# [3 rows x 8170 columns]

# %%
DOLLAR_VOLUME = VOLUME * PRICE
DOLLAR_VOLUME
# Out:
#                     AIR           ABT        WDDD           ACU         AE  \
# date
# 2009-04-15   4819620.00  2.377736e+09      0.0000  7.430000e+02    4395.00
# 2009-04-16   5468544.00  1.293806e+09      0.0000  7.600000e+03   10388.00
# 2009-04-17   4611680.00  1.409053e+09      0.0000  4.608000e+04   27000.00
# 2009-04-20   4400541.00  1.136120e+09      0.0000  2.287800e+04   43500.00
# 2009-04-21   5079690.00  8.675134e+08      0.0000  3.547200e+04   53650.00
# ...                 ...           ...         ...           ...        ...
# 2021-04-12   5905819.92  3.529496e+08  11473.9525  6.179567e+05  573300.00
# 2021-04-13  10349690.49  6.082314e+08   7568.7150  2.684607e+05  157486.86
# 2021-04-14   6526215.28  5.742982e+08   9006.6600  8.710716e+04  295281.95
# 2021-04-15   6183536.56  5.590802e+08  82929.7550  1.223447e+06  436967.44
# 2021-04-16   5586814.05  7.763255e+08  57530.4000  1.006941e+06  199962.00
#
# ...

# %%
def calculate_quarterly_annual_values(item):                        # item: table with shortest and longest values and quarters.
    result           = pd.DataFrame()                               # Results go here.
    all_firms        = item.index.get_level_values('cik').unique()  # All CIKs.
    all_filing_dates = pd.read_csv('data/sec/dates/filing_dates.csv', index_col='cik', parse_dates=['filed'])
    
    for cik in all_firms:                                           # Loop over all firms.  
        filing_dates = pd.Series(all_filing_dates.filed[cik])       # All filing dates for this firm.

        # Quarterly values:
        valuesQ = item.loc[cik].value_shortest.reindex(filing_dates) # Values with shortest reported quarters.
        qtrsQ   = item.loc[cik].qtrs_shortest.astype(int)           # Number of quarters for each value.
        for date,q in qtrsQ[qtrsQ>1].iteritems():                   # Loop over all dates with > 1 quarters. 
            previous_values = valuesQ[:date][-q:-1]                 # Example: for q=3 we need to subtract 2 previous quarters.            
            if len(previous_values) == q-1:                         # If all previous values available.
                valuesQ[date] -= previous_values.sum(skipna=False)  # Subtract previous values to get quarterly value.
            else:
                valuesQ[date]  = np.nan                  

        # Annual values:
        valuesA = item.loc[cik].value_longest.reindex(filing_dates) # Values with longest reported quarters.
        qtrsA   = item.loc[cik].qtrs_longest.astype(int)            # Number of quarters for each value.
        for date,q in qtrsA[qtrsA<4].iteritems():                   # Loop over all dates with < 4 quarters. 
            previous_values = valuesQ[:date][-4:-q]                 # Example: for q=2 we need to add quarters -3 and -4.
            if len(previous_values) == 4-q:                         # If all previous data available.     
                valuesA[date] += previous_values.sum(skipna=False)  # Add previous values to get annual values.
            else:
                valuesA[date]  = np.nan        
        
        result = result.append( pd.DataFrame({'cik':cik, 'filed':filing_dates, 'valueQ':valuesQ.values, 'valueA':valuesA.values}) )

    return result.set_index(['cik','filed'])                        # Return a table with columns 'valueQ' and 'valueA'.



earnigns = calculate_quarterly_annual_values(items['earnings'])

# %%
x = ffill_values(earnings.valueA, trading_days)
x
# Out:
# cik           1750          1800       1961     2034       2098      2178     \
# date
# 2009-04-15        NaN           NaN        NaN      NaN        NaN       NaN
# 2009-04-16        NaN           NaN        NaN      NaN        NaN       NaN
# 2009-04-17        NaN           NaN        NaN      NaN        NaN       NaN
# 2009-04-20        NaN           NaN        NaN      NaN        NaN       NaN
# 2009-04-21        NaN           NaN        NaN      NaN        NaN       NaN
# ...               ...           ...        ...      ...        ...       ...
# 2021-04-20  5300000.0  4.473000e+09 -1568639.0      NaN  8098766.0  995000.0
# 2021-04-21  5300000.0  4.473000e+09 -1568639.0      NaN  8098766.0  995000.0
# 2021-04-22  5300000.0  4.473000e+09 -1568639.0      NaN  8098766.0  995000.0
# 2021-04-23  5300000.0  4.473000e+09 -1568639.0      NaN  8098766.0  995000.0
# 2021-04-26  5300000.0  4.473000e+09 -1568639.0      NaN  8098766.0  995000.0
#
# ...

# %%
symbols = pd.read_csv('data/ticker_symbols/symbols.csv',index_col=0)
symbols[:3]
# Out:
#      ticker                title exchange assetType priceCurrency   startDate  \
# cik
# 1750    AIR             AAR CORP     NYSE     Stock           USD  1984-07-19
# 1800    ABT  ABBOTT LABORATORIES     NYSE     Stock           USD  1983-04-06
# 1961   WDDD           WORLDS INC    OTCQB     Stock           USD  1998-10-20
#
#          endDate
# cik
# 1750  2021-04-16
# 1800  2021-04-16
# 1961  2021-04-16

# %%
list = x.rename(columns = symbols.ticker)['2014'].iloc[-1].nlargest(10).index
list
# Out:
# Index(['AAPL', 'XOM', 'WFC', 'MSFT', 'BRK-A', 'CVX', 'JPM', 'T', 'JNJ', 'VZ'], dtype='object', name='cik')

# %%
DOLLAR_VOLUME[list]['2014'].iloc[-1].idxmin()
# Out:
# 'BRK-A'

# %% [markdown]
# Question 8

# %%
new_list = DOLLAR_VOLUME['2018'].mean().nlargest(500).index

# %%
VOLUME['2019'][-1:][new_list].sum('columns')
# Out:
# date
# 2019-12-31    1.730147e+09
# dtype: float64

# %% [markdown]
# Question 9

# %% [markdown]
# Question 10

# %%
RET = pd.read_csv('data/tiingo/adjClose.csv', index_col='date', parse_dates=['date']).pct_change()

# %%
def get_rebalance_dates(frequency, start_date):
    price = PRICE[PRICE.index>start_date]
    group = getattr(price.index, frequency) 
    return price[:1].index.union(price.groupby([price.index.year, group]).tail(1).index)



def run_backtest(frequency, backtest_start='1900-1-1'):   
    
    rebalance_dates = get_rebalance_dates(frequency, backtest_start) 

    portfolio_value = pd.Series(1,                        index=[rebalance_dates[0]])    
    weights         = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])
    trades          = pd.DataFrame(columns=PRICE.columns, index=[rebalance_dates[0]])

    previous_positions = weights.iloc[0]
        
    for i in range(1, len(rebalance_dates)-1):
        start_date = rebalance_dates[i]
        end_date   = rebalance_dates[i+1]

        cum_ret = RET[start_date:end_date][1:].add(1).cumprod()
        
        assets        = select_assets(start_date)               # Call "select_assets()"  function to get the assets.
        start_weights = select_weights(start_date, assets)      # Call "select_weights()" function to get the weights
            
        new_positions = portfolio_value.iloc[-1] * start_weights   

        start_to_end_positions = new_positions * cum_ret
        start_to_end_value     = start_to_end_positions.sum('columns')

        portfolio_value = portfolio_value.append(start_to_end_value) 
                
        weights = weights.append(start_to_end_positions.div(start_to_end_value,'rows'))                 
                
        trades.loc[start_date] = new_positions - previous_positions 
        previous_positions     = start_to_end_positions.iloc[-1]      # Previous positions for the next rebalance round

    return portfolio_value, weights, trades

# %%
def select_assets(date):
        assets = DOLLAR_VOLUME[:date][-100:].mean().nlargest(5).index
        return assets

def select_weights(date, assets):      
    w = pd.Series(1/len(assets), index=assets)   
    return w

# %%
portfolio, weights, trades = run_backtest('month', '2011-1-1')

portfolio
# Out:
# 2011-01-03    1.000000
# 2011-02-01    1.023225
# 2011-02-02    1.017598
# 2011-02-03    1.019025
# 2011-02-04    1.019954
#                 ...
# 2021-04-12    9.206357
# 2021-04-13    9.501396
# 2021-04-14    9.262984
# 2021-04-15    9.309793
# 2021-04-16    9.347412
# Length: 2570, dtype: float64

# %%
portfolio['2021-03'][-1]*100
# Out:
# 875.8241413740539

# %%
# Working with data:
import numpy  as np                                   # For scientific computing.
import pandas as pd                                   # Working with tables.

# Downloading files:
import requests, zipfile, io                                # To access websites.

import os

# Specific data providers:
from tiingo import TiingoClient                       # Stock prices.
import quandl                                         # Economic data, futures prices, ...

# API keys:
tiingo = TiingoClient({'api_key':'f10f5d79cf2567b045cc7e9b595a6fec0f5321d2'})
quandl.ApiConfig.api_key = 'EqpCyveK1jFmUkmzpPjz'

# Plotting:
import matplotlib.pyplot as plt                        # Basic plot library.
plt.style.use('ggplot')                                # Make plots look nice

# %%
pd.read_csv('data/sec/merged/2015q4.csv', parse_dates=['filed','ddate'])
# Out:
#             cik     sic countryinc  \
# 0          3545   100.0         US
# 1          3545   100.0         US
# 2          3545   100.0         US
# 3          3545   100.0         US
# 4          3545   100.0         US
# ...         ...     ...        ...
# 2226063  801348  6500.0         US
# 2226064  801348  6500.0         US
# 2226065  801348  6500.0         US
# 2226066  801348  6500.0         US
# 2226067  801348  6500.0         US
#
#                                                        tag      filed  \
# 0                                   AccountsPayableCurrent 2015-12-10
# 1                                   AccountsPayableCurrent 2015-12-10
# 2                             AccountsReceivableNetCurrent 2015-12-10
# 3                             AccountsReceivableNetCurrent 2015-12-10
# 4                                AccruedLiabilitiesCurrent 2015-12-10
# ...                                                    ...        ...
# ...

# %%
def get_items_from_SEC_files(tags, filename=None):                # Function input: list of tags, optional filename.

    directory = 'data/sec/merged/'                                # Read data from here.
    filenames = [filename] if filename else os.listdir(directory) # Supplied filename or all files in "merged" directory.
    filenames = [f for f in filenames if not f.startswith(".")]   # Exclude hidden files from file list.

    results   = {t:pd.DataFrame() for t in tags}                  # Dictionary of tables (1 table for each tag)

    for filename in sorted(filenames):                            # Loop over all files.
        print(filename)
        data = pd.read_csv(directory+filename, parse_dates=['filed','ddate'])  # Read the file.
        
        for t in tags:                                            # Loop over all tags.
            item  = data[data.tag==t]                             # Select all data for this tag.
            short = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,False]) # Samllest qrts.
            long  = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,True])  # Largest  qtrs.
            short = short.groupby(['cik','filed']).last()[['value','qtrs']]     # One value for each firm and filing.
            long  = long .groupby(['cik','filed']).last()[['value','qtrs']]     
            short_long = short.join(long, lsuffix='_shortest', rsuffix='_longest') # Put shortest and longest next to each other.
            results[t] = results[t].append( short_long )  
                        
    for t in tags:                                                # Now sort all tables by filing date.
        if not results[t].empty: results[t] = results[t].sort_index(level='filed')            

    return results

# %%
x = get_items_from_SEC_files(['CashAndCashEquivalentsAtCarryingValue'], '2015q4.csv')
# Out:
# 2015q4.csv

# %%
x['CashAndCashEquivalentsAtCarryingValue']
# Out:
#                     value_shortest  qtrs_shortest  value_longest  qtrs_longest
# cik     filed
# 7623    2015-10-01        643540.0              0       643540.0             0
# 10329   2015-10-01      20600000.0              0     20600000.0             0
# 704172  2015-10-01         10654.0              0        10654.0             0
# 730255  2015-10-01     100098000.0              0    100098000.0             0
# 824416  2015-10-01          7886.0              0         7886.0             0
# ...                            ...            ...            ...           ...
# 1628104 2015-12-30          2315.0              0         2315.0             0
# 1354591 2015-12-31            55.0              0           55.0             0
# 1451433 2015-12-31         56898.0              0        56898.0             0
# 1515620 2015-12-31             NaN              0            NaN             0
# 1563915 2015-12-31         69102.0              0        69102.0             0
#
# ...

# %%
x
# Out:
# {'CashAndCashEquivalentsAtCarryingValue':                     value_shortest  qtrs_shortest  value_longest  qtrs_longest
#  cik     filed
#  7623    2015-10-01        643540.0              0       643540.0             0
#  10329   2015-10-01      20600000.0              0     20600000.0             0
#  704172  2015-10-01         10654.0              0        10654.0             0
#  730255  2015-10-01     100098000.0              0    100098000.0             0
#  824416  2015-10-01          7886.0              0         7886.0             0
#  ...                            ...            ...            ...           ...
#  1628104 2015-12-30          2315.0              0         2315.0             0
#  1354591 2015-12-31            55.0              0           55.0             0
#  1451433 2015-12-31         56898.0              0        56898.0             0
#  1515620 2015-12-31             NaN              0            NaN             0
# ...

# %%
z = pd.read_csv('data/sec/merged/2015q4.csv', parse_dates=['filed','ddate'])
z
# Out:
#             cik     sic countryinc  \
# 0          3545   100.0         US
# 1          3545   100.0         US
# 2          3545   100.0         US
# 3          3545   100.0         US
# 4          3545   100.0         US
# ...         ...     ...        ...
# 2226063  801348  6500.0         US
# 2226064  801348  6500.0         US
# 2226065  801348  6500.0         US
# 2226066  801348  6500.0         US
# 2226067  801348  6500.0         US
#
#                                                        tag      filed  \
# 0                                   AccountsPayableCurrent 2015-12-10
# 1                                   AccountsPayableCurrent 2015-12-10
# 2                             AccountsReceivableNetCurrent 2015-12-10
# 3                             AccountsReceivableNetCurrent 2015-12-10
# 4                                AccruedLiabilitiesCurrent 2015-12-10
# ...                                                    ...        ...
# ...

# %%
z[z.tag == 'CashAndCashEquivalentsAtCarryingValue']
# Out:
#              cik     sic countryinc                                    tag  \
# 12          3545   100.0         US  CashAndCashEquivalentsAtCarryingValue
# 13          3545   100.0         US  CashAndCashEquivalentsAtCarryingValue
# 14          3545   100.0         US  CashAndCashEquivalentsAtCarryingValue
# 15          3545   100.0         US  CashAndCashEquivalentsAtCarryingValue
# 652         4127  3674.0         US  CashAndCashEquivalentsAtCarryingValue
# ...          ...     ...        ...                                    ...
# 2225095  1278680  6221.0         US  CashAndCashEquivalentsAtCarryingValue
# 2225288  1535365  6221.0         US  CashAndCashEquivalentsAtCarryingValue
# 2225289  1535365  6221.0         US  CashAndCashEquivalentsAtCarryingValue
# 2225290  1535365  6221.0         US  CashAndCashEquivalentsAtCarryingValue
# 2225291  1535365  6221.0         US  CashAndCashEquivalentsAtCarryingValue
#
#              filed      ddate  qtrs        value
# ...
