# %% [markdown]
# ## Get Items from SEC Data

# %%
import pandas as pd
import requests, zipfile, io
import os
from pathlib import Path

# %% [markdown]
# Get latest file from SEC (https://www.sec.gov/dera/data/financial-statement-and-notes-data-set.html):

# %%
def download_file(period):
    url = 'https://www.sec.gov/files/dera/data/financial-statement-and-notes-data-sets/'+period+'_notes.zip'
    
    unzip_folder_name = 'data/sec/downloads/' + period                           # Where to put contents of unzipped file  
    
    r = requests.get(url)
    if r.ok:                                                                     # If download worked
        print('Downloaded:', url, 'to:', unzip_folder_name)
        Path(unzip_folder_name).mkdir(parents=True, exist_ok=True)            
        z = zipfile.ZipFile(io.BytesIO(r.content))
        z.extractall(members=['sub.tsv','num.tsv'], path=unzip_folder_name)
    else:
        print('File not found')
        
        
def merge_sec_files(folder):

    keep_these_columns = ['cik','sic','countryinc','tag','filed','ddate','qtrs','value']

    filings = pd.read_table('data/sec/downloads/'+folder+'/sub.tsv')
    numbers = pd.read_table('data/sec/downloads/'+folder+'/num.tsv', encoding='ISO-8859-1', error_bad_lines=False) 

    filings = filings[filings.form.isin(['10-Q','10-K']) & filings.cik.notnull()]
    numbers = numbers[(numbers.dimh=='0x00000000')]                                     # keep only non-segment data

    merged = numbers.merge(filings, on='adsh', how='inner')[keep_these_columns]

    merged['filed'] = pd.to_datetime(merged.filed, format='%Y%m%d', errors='coerce')    #  ‘coerce’: invalid parsing set as NaT.
    merged['ddate'] = pd.to_datetime(merged.ddate, format='%Y%m%d', errors='coerce')    

    merged = merged[merged.filed.notnull() & merged.ddate.notnull()].drop_duplicates()

    merged.to_csv('data/sec/merged/'+folder+'.csv', index=False)
    
    return merged

# %%
download_file('2021_01')
# Out:
# Downloaded: https://www.sec.gov/files/dera/data/financial-statement-and-notes-data-sets/2021_01_notes.zip to: data/sec/downloads/2021_01

# %%
merge_sec_files('2021_01')
# Out:
#             cik     sic countryinc  \
# 0       1517389  7371.0         US
# 1       1517389  7371.0         US
# 2       1517389  7371.0         US
# 3       1517389  7371.0         US
# 4       1517389  7371.0         US
# ...         ...     ...        ...
# 118256  1593812  6221.0         US
# 118257  1593812  6221.0         US
# 118258  1593812  6221.0         US
# 118259  1593812  6221.0         US
# 118260  1593812  6221.0         US
#
#                                                 tag      filed      ddate  \
# 0       AccountsPayableAndAccruedLiabilitiesCurrent 2021-01-06 2020-11-30
# 1       AccountsPayableAndAccruedLiabilitiesCurrent 2021-01-06 2020-02-29
# 2                      AccountsReceivableNetCurrent 2021-01-06 2020-11-30
# 3                      AccountsReceivableNetCurrent 2021-01-06 2020-02-29
# 4                           AdditionalPaidInCapital 2021-01-06 2020-11-30
# ...                                             ...        ...        ...
# 118256                         RedemptionsCostBasis 2021-01-29 2019-10-31
# 118257                         RedemptionsCostBasis 2021-01-29 2020-10-31
# 118258          WeightedAverageNumberOfGoldReceipts 2021-01-29 2018-10-31
# 118259          WeightedAverageNumberOfGoldReceipts 2021-01-29 2019-10-31
# 118260          WeightedAverageNumberOfGoldReceipts 2021-01-29 2020-10-31
#
#         qtrs        value
# 0          0       7094.0
# 1          0       8698.0
# 2          0       9384.0
# 3          0       9402.0
# 4          0    2449733.0
# ...      ...          ...
# 118256     4      -6713.0
# 118257     4 -203243901.0
# 118258     4     194219.0
# 118259     4     153340.0
# 118260     4      44533.0
#
# [106707 rows x 8 columns]

# %% [markdown]
# Read example file:

# %%
directory = 'data/sec/merged/'
filename  = '2010q2.csv'
data      = pd.read_csv(directory+filename, parse_dates=['filed','ddate'])
data
# Out:
#            cik   sic countryinc  \
# 0      1063761  6798         US
# 1      1063761  6798         US
# 2      1063761  6798         US
# 3      1063761  6798         US
# 4      1063761  6798         US
# ...        ...   ...        ...
# 96107  1032208  4932         US
# 96108  1135971  4931         US
# 96109   934612  4011        NaN
# 96110   934612  4011        NaN
# 96111  1458891  1381         CH
#
#                                                    tag      filed      ddate  \
# 0                        AccountsAndNotesReceivableNet 2010-05-10 2009-12-31
# 1                        AccountsAndNotesReceivableNet 2010-05-10 2010-03-31
# 2      AccumulatedOtherComprehensiveIncomeLossNetOfTax 2010-05-10 2009-12-31
# 3      AccumulatedOtherComprehensiveIncomeLossNetOfTax 2010-05-10 2010-03-31
# 4                              AdditionalPaidInCapital 2010-05-10 2009-12-31
# ...                                                ...        ...        ...
# 96107               EntityCommonStockSharesOutstanding 2010-05-04 2010-03-31
# 96108               EntityCommonStockSharesOutstanding 2010-05-07 2010-03-31
# 96109               EntityCommonStockSharesOutstanding 2010-05-07 2010-03-31
# 96110                                EntityPublicFloat 2010-05-07 2009-06-30
# 96111                                EntityPublicFloat 2010-05-07 2009-06-30
#
#        qtrs         value
# 0         0  4.027290e+08
# 1         0  3.554690e+08
# 2         0 -3.088000e+06
# 3         0 -2.751700e+07
# 4         0  7.547959e+09
# ...     ...           ...
# 96107     0  2.475390e+08
# 96108     0  2.232103e+08
# 96109     0  0.000000e+00
# 96110     0  2.479400e+10
# 96111     0  7.800000e+09
#
# [96112 rows x 8 columns]

# %% [markdown]
# Get all earnings:

# %%
tag  = 'NetIncomeLoss'
item = data[data.tag==tag]
item
# Out:
#            cik   sic countryinc            tag      filed      ddate  qtrs  \
# 302     899881  6798         US  NetIncomeLoss 2010-05-05 2010-03-31     1
# 303     899881  6798         US  NetIncomeLoss 2010-05-05 2009-03-31     1
# 543     895648  6798         US  NetIncomeLoss 2010-05-12 2010-03-31     1
# 544     895648  6798         US  NetIncomeLoss 2010-05-12 2009-03-31     1
# 824     315189  3523         US  NetIncomeLoss 2010-05-28 2009-04-30     2
# ...        ...   ...        ...            ...        ...        ...   ...
# 95426   310522  6111        NaN  NetIncomeLoss 2010-05-10 2010-03-31     1
# 95771  1032033  6141         US  NetIncomeLoss 2010-05-06 2009-03-31     1
# 95772  1032033  6141         US  NetIncomeLoss 2010-05-06 2010-03-31     1
# 96014  1022646  1311        NaN  NetIncomeLoss 2010-05-05 2010-03-31     1
# 96015  1022646  1311        NaN  NetIncomeLoss 2010-05-05 2009-03-31     1
#
#               value
# 302   -8.476000e+07
# 303    1.851010e+08
# 543    5.165600e+07
# 544   -3.960820e+08
# 824    6.762000e+08
# ...             ...
# 95426 -1.153000e+10
# 95771 -2.138600e+07
# 95772  2.401400e+08
# 96014  2.023760e+08
# 96015 -5.125880e+08
#
# [923 rows x 8 columns]

# %% [markdown]
# Get SEC file with ticker symbols:

# %%
symbols = pd.read_json('https://www.sec.gov/files/company_tickers.json').transpose().set_index('cik_str')
symbols
# Out:
#           ticker                                  title
# cik_str
# 320193      AAPL                             Apple Inc.
# 789019      MSFT                         MICROSOFT CORP
# 1018724     AMZN                         AMAZON COM INC
# 1652044     GOOG                          Alphabet Inc.
# 1293451    TCEHY                   Tencent Holdings Ltd
# ...          ...                                    ...
# 1819516  ASPL-WT  Aspirational Consumer Lifestyle Corp.
# 1819574  STIC-UN        Northern Star Acquisition Corp.
# 1819574  STIC-WT        Northern Star Acquisition Corp.
# 1819584  SNPR-UN          Tortoise Acquisition Corp. II
# 1819584  SNPR-WT          Tortoise Acquisition Corp. II
#
# [10906 rows x 2 columns]

# %% [markdown]
# Find CIKs for Apple and Amazon:

# %%
apple = symbols[symbols.ticker=='AAPL'].index[0]  
apple
# Out:
# 320193

# %%
amazon = symbols[symbols.ticker=='AMZN'].index[0] 
amazon
# Out:
# 1018724

# %% [markdown]
# Get all repoted earnings for these two firms:

# %%
t = item[item.cik.isin([320193, 1018724])] # could also search for 'apple' and 'amazon', the variables we assigned the cik above
t
# Out:
#            cik   sic countryinc            tag      filed      ddate  qtrs  \
# 36575  1018724  5961         US  NetIncomeLoss 2010-04-23 2009-03-31     4
# 36576  1018724  5961         US  NetIncomeLoss 2010-04-23 2010-03-31     4
# 36577  1018724  5961         US  NetIncomeLoss 2010-04-23 2009-03-31     1
# 36578  1018724  5961         US  NetIncomeLoss 2010-04-23 2010-03-31     1
# 57500   320193  3571         US  NetIncomeLoss 2010-04-21 2010-03-31     2
# 57501   320193  3571         US  NetIncomeLoss 2010-04-21 2009-03-31     2
# 57502   320193  3571         US  NetIncomeLoss 2010-04-21 2009-03-31     1
# 57503   320193  3571         US  NetIncomeLoss 2010-04-21 2010-03-31     1
#
#               value
# 36575  6.790000e+08
# 36576  1.024000e+09
# 36577  1.770000e+08
# 36578  2.990000e+08
# 57500  6.452000e+09
# 57501  3.875000e+09
# 57502  1.620000e+09
# 57503  3.074000e+09

# %% [markdown]
# We want: for each company and each filing: most recent period and shortest quarters.
# Step 1: sort:

# %%
shortest = t.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,False])
shortest
# Out:
#            cik   sic countryinc            tag      filed      ddate  qtrs  \
# 57501   320193  3571         US  NetIncomeLoss 2010-04-21 2009-03-31     2
# 57502   320193  3571         US  NetIncomeLoss 2010-04-21 2009-03-31     1
# 57500   320193  3571         US  NetIncomeLoss 2010-04-21 2010-03-31     2
# 57503   320193  3571         US  NetIncomeLoss 2010-04-21 2010-03-31     1
# 36575  1018724  5961         US  NetIncomeLoss 2010-04-23 2009-03-31     4
# 36577  1018724  5961         US  NetIncomeLoss 2010-04-23 2009-03-31     1
# 36576  1018724  5961         US  NetIncomeLoss 2010-04-23 2010-03-31     4
# 36578  1018724  5961         US  NetIncomeLoss 2010-04-23 2010-03-31     1
#
#               value
# 57501  3.875000e+09
# 57502  1.620000e+09
# 57500  6.452000e+09
# 57503  3.074000e+09
# 36575  6.790000e+08
# 36577  1.770000e+08
# 36576  1.024000e+09
# 36578  2.990000e+08

# %% [markdown]
# Step 2: group (we want 1 observation per filing):

# %%
shortest.groupby(['cik','filed']).last()
# Out:
#                      sic countryinc            tag      ddate  qtrs  \
# cik     filed
# 320193  2010-04-21  3571         US  NetIncomeLoss 2010-03-31     1
# 1018724 2010-04-23  5961         US  NetIncomeLoss 2010-03-31     1
#
#                            value
# cik     filed
# 320193  2010-04-21  3.074000e+09
# 1018724 2010-04-23  2.990000e+08

# %% [markdown]
# Same for longest quarters:

# %%
longest = t.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,True])

longest.groupby(['cik','filed']).last()
# Out:
#                      sic countryinc            tag      ddate  qtrs  \
# cik     filed
# 320193  2010-04-21  3571         US  NetIncomeLoss 2010-03-31     2
# 1018724 2010-04-23  5961         US  NetIncomeLoss 2010-03-31     4
#
#                            value
# cik     filed
# 320193  2010-04-21  6.452000e+09
# 1018724 2010-04-23  1.024000e+09

# %% [markdown]
# Now do this for all firms:

# %%
shortest = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,False])
longest  = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,True])

shortest = shortest.groupby(['cik','filed']).last()     # Most recent, shortest for each firm and filing.
longest  = longest .groupby(['cik','filed']).last()     # Most recent, longest for each firm and filing.  

shortest
# Out:
#                      sic countryinc            tag      ddate  qtrs  \
# cik     filed
# 2969    2010-04-26  2810         US  NetIncomeLoss 2010-03-31     1
# 3673    2010-05-07  4911         US  NetIncomeLoss 2010-03-31     1
# 4127    2010-05-11  3674         US  NetIncomeLoss 2010-03-31     1
# 4281    2010-04-22  3350         US  NetIncomeLoss 2010-03-31     1
# 4447    2010-05-07  2911         US  NetIncomeLoss 2010-03-31     1
# ...                  ...        ...            ...        ...   ...
# 1451505 2010-05-05  1381         CH  NetIncomeLoss 2010-03-31     1
# 1453090 2010-05-03  1381         CH  NetIncomeLoss 2010-03-31     1
# 1465112 2010-05-07  4899         US  NetIncomeLoss 2010-03-31     1
# 1466258 2010-05-07  3822         IE  NetIncomeLoss 2010-03-31     1
# 1467373 2010-06-25  7389         IE  NetIncomeLoss 2010-05-31     1
#
#                           value
# cik     filed
# 2969    2010-04-26  252000000.0
# 3673    2010-05-07   88200000.0
# 4127    2010-05-11   27744000.0
# 4281    2010-04-22 -201000000.0
# 4447    2010-05-07  538000000.0
# ...                         ...
# 1451505 2010-05-05  677000000.0
# 1453090 2010-05-03  -40009000.0
# 1465112 2010-05-07  558000000.0
# 1466258 2010-05-07    1400000.0
# 1467373 2010-06-25  490597000.0
#
# [403 rows x 6 columns]

# %% [markdown]
# Repeat this for multiple quarters:

# %%
tag = 'EarningsPerShareBasic'

directory = 'data/sec/merged/'                           
filenames = ['2020q1.csv','2020q2.csv','2020q3.csv', '2020_10.csv', '2020_11.csv','2020_12.csv','2021_01.csv']

values_short   = pd.DataFrame()        # Values measured over shortest duration (smallest qtrs).
values_long    = pd.DataFrame()        # Values measured over longest  duration (largest qtrs).

for filename in filenames:                                # Loop over all files.
    print(filename)
    data = pd.read_csv(directory+filename, parse_dates=['filed','ddate'])  # Read the file.

    item  = data[data.tag==tag]                         # Select all data for this tag.

    short = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,False])
    long  = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,True])
    short = short.groupby(['cik','filed']).last()     # Most recent, shortests for each firm and filing.
    long  = long .groupby(['cik','filed']).last()     # Most recent, longest   for each firm and filing.            
    
    values_short   = values_short  .append( short[['value','qtrs']])  
    values_long    = values_long   .append( long [['value','qtrs']])
# Out:
# 2020q1.csv
# 2020q2.csv
# 2020q3.csv
# 2020_10.csv
# 2020_11.csv
# 2020_12.csv
# 2021_01.csv

# %% [markdown]
# Check results, get all values for Apple:

# %%
cik = symbols[symbols.ticker=='GOOG'].index[0]  

values_short.value.unstack(level = 0)[cik].dropna()
# Out:
# filed
# 2020-02-04    49.59
# 2020-04-29     9.96
# 2020-07-31    10.21
# 2020-10-30    16.55
# Name: 1652044, dtype: float64

# %% [markdown]
# Corresponding quarters:

# %%
values_short.qtrs.unstack(level = 0)[cik].dropna()
# Out:
# filed
# 2020-01-29    1.0
# 2020-05-01    1.0
# 2020-07-31    1.0
# 2020-10-30    1.0
# 2021-01-28    1.0
# Name: 320193, dtype: float64

# %% [markdown]
# Long values:

# %%
values_long.value.unstack(level = 0)[cik].dropna()
# Out:
# filed
# 2020-02-04    49.59
# 2020-04-29     9.96
# 2020-07-31    20.16
# 2020-10-30    36.69
# Name: 1652044, dtype: float64

# %% [markdown]
# Quarters:

# %%
values_long.qtrs.unstack(level = 0)[cik].dropna()
# Out:
# filed
# 2020-02-04    4.0
# 2020-04-29    1.0
# 2020-07-31    2.0
# 2020-10-30    3.0
# Name: 1652044, dtype: float64

# %% [markdown]
# We can also unstack these tables:

# %% [markdown]
# Get multiple tags simultaneously:

# %%
def get_items(tags, filename=None):                     # Function input: list of tags, optional filename.

    directory = 'data/sec/merged/'                            # Read data from here.
    filenames = [filename] if filename else os.listdir(directory) # Supplied filename or all files in "merged" directory.

    values_short   = {t:pd.DataFrame() for t in tags}         # Values measured over shortest duration (smallest qtrs).
    values_long    = {t:pd.DataFrame() for t in tags}         # Values measured over longest  duration (largest qtrs).

    for filename in filenames:                                # Loop over all files.
        print(filename)
        data = pd.read_csv(directory+filename, parse_dates=['filed','ddate'])  # Read the file.
        
        for t in tags:                                        # Loop over all tags.
            item  = data[data.tag==t]                         # Select all data for this tag.
            short = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,False])
            long  = item.sort_values(['cik','filed','ddate','qtrs'], ascending=[True,True,True,True])
            short = short.groupby(['cik','filed']).last()     # Most recent, shortests for each firm and filing.
            long  = long .groupby(['cik','filed']).last()     # Most recent, longest   for each firm and filing.            
            values_short  [t] = values_short  [t].append( short[['value','qtrs']] )  
            values_long   [t] = values_long   [t].append( long [['value','qtrs']] )         
                        
    for t in tags:                                            # Now sort all tables by filing date.
        if not values_short  [t].empty:   values_short  [t] = values_short  [t].unstack(level=0).sort_values('filed')
        if not values_long   [t].empty:   values_long   [t] = values_long   [t].unstack(level=0).sort_values('filed')

    return values_short, values_long

# %% [markdown]
# Run this function like this:

# %%
vs, vl = get_items(['ResearchAndDevelopmentExpense','NetIncomeLoss'])

# %% [markdown]
# Plot R&D of Apple:
